# %% [markdown]
# # ECE 590 - Lab2 - LeNet5 Cifar 10 - Anthony DiSpirito

# %% [markdown]
# ## My Info
# * **Name: Anthony DiSpirito**
# * **NetID: ad424**
# * **Class: ECE 590 - Comp Eng ML and DL**
# * **Title: Lab2 - My Model**
# * **Date: 10/2/19**

# %% [markdown]
# ## Build My Model

# %% [markdown]
# ### Import Statements

# %%
import argparse
import os, sys
import math
import random
import time
import datetime
import numpy as py

# Import pytorch dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import torch.backends.cudnn as cudnn
from tqdm import tqdm_notebook as tqdm

# You cannot change this line.
from tools.dataloader import CIFAR10

# %% [markdown]
# ### My Model Class

# %%
""" 
Assignment 2(a)
Build the LeNet-5 model by following table 1 or figure 1.

You can also insert batch normalization and leave the LeNet-5 
with batch normalization here for assignment 3(c).
"""
# Create the neural network module:
class convBlock(nn.Module):
    def __init__(self, k, channel_in, channel_out, layers, padding):
        super(convBlock, self).__init__()
        self.layers = layers
        if padding == False:
            self.conv1 = nn.Conv2d(channel_in, channel_out, k, padding=0, dilation=1,
                                   groups=1, bias=True, padding_mode='zeros')
            self.bn_conv1 = nn.BatchNorm2d(channel_out, eps=1e-05,momentum=0.1, 
                                       affine=True, track_running_stats=True)
            if layers > 1:
                self.conv2 = nn.Conv2d(channel_out, channel_out, k, padding=0, dilation=1,
                                   groups=1, bias=True, padding_mode='zeros')
                self.bn_conv2 = nn.BatchNorm2d(channel_out, eps=1e-05,momentum=0.1, 
                                       affine=True, track_running_stats=True)
                if layers > 2:
                    self.conv3 = nn.Conv2d(channel_out, channel_out, k, padding=0, dilation=1,
                                   groups=1, bias=True, padding_mode='zeros')
                    self.bn_conv3 = nn.BatchNorm2d(channel_out, eps=1e-05,momentum=0.1, 
                                       affine=True, track_running_stats=True)
                    if layers > 3:
                        self.conv4 = nn.Conv2d(channel_out, channel_out, k, padding=0, dilation=1,
                                   groups=1, bias=True, padding_mode='zeros')
                        self.bn_conv4 = nn.BatchNorm2d(channel_out, eps=1e-05,momentum=0.1, 
                                       affine=True, track_running_stats=True)
            
        else:
            self.conv1 = nn.Conv2d(channel_in, channel_out, k, padding=k//2, dilation=1,
                                   groups=1, bias=True, padding_mode='zeros')
            self.bn_conv1 = nn.BatchNorm2d(channel_out, eps=1e-05,momentum=0.1, 
                                       affine=True, track_running_stats=True)
            if layers > 1:
                self.conv2 = nn.Conv2d(channel_out, channel_out, k, padding=k//2, dilation=1,
                                   groups=1, bias=True, padding_mode='zeros')
                self.bn_conv2 = nn.BatchNorm2d(channel_out, eps=1e-05,momentum=0.1, 
                                       affine=True, track_running_stats=True)
                if layers > 2:
                    self.conv3 = nn.Conv2d(channel_out, channel_out, k, padding=k//2, dilation=1,
                                   groups=1, bias=True, padding_mode='zeros')
                    self.bn_conv3 = nn.BatchNorm2d(channel_out, eps=1e-05,momentum=0.1, 
                                       affine=True, track_running_stats=True)
                    if layers > 3:
                        self.conv4 = nn.Conv2d(channel_out, channel_out, k, padding=k//2, dilation=1,
                                   groups=1, bias=True, padding_mode='zeros')
                        self.bn_conv4 = nn.BatchNorm2d(channel_out, eps=1e-05,momentum=0.1, 
                                       affine=True, track_running_stats=True)
    def forward(self, x):
        out = F.elu(self.bn_conv1(self.conv1(x)))
        if self.layers > 1:
            out = F.elu(self.bn_conv2(self.conv2(out)))
            if self.layers > 2:
                out = F.elu(self.bn_conv3(self.conv3(out)))
                if self.layers > 3:
                    out = F.elu(self.bn_conv4(self.conv4(out)))
        out = F.max_pool2d(out, 2)
        return out
        
class TONY_NET(nn.Module):
    def __init__(self):
        super(TONY_NET, self).__init__()
        # padding = k//2
        #self.Dropout2d(p=0.5, inplace=False)
        self.convBlock1 = convBlock(k = 3, channel_in = 3, channel_out = 64, layers = 2, padding = True)
        self.convBlock2 = convBlock(k = 3, channel_in = 64, channel_out = 128, layers = 2, padding = True)
        orig_input_size = 32 # 32x32
        number_of_conv_block_poolings = 2
        pooling_size = 2 # 2x2 with stride 2
        num_features = int(128*(orig_input_size*(1/(pooling_size**number_of_conv_block_poolings)))**2)
        self.fc1 = nn.Linear(num_features, 128, bias = True)
        torch.nn.init.xavier_normal_(self.fc1.weight)
        self.dropout_fc1 = nn.Dropout(p = 0.5)
        self.fc2 = nn.Linear(128, 10, bias = True)
        torch.nn.init.xavier_normal_(self.fc2.weight)
        return
    
    def forward(self, x):
        out = self.convBlock1(x)
        out = self.convBlock2(out)
        out = out.view(out.size(0), -1)
        out = F.elu(self.fc1(out))
        out = self.dropout_fc1(out)
        out = self.fc2(out)
        return out

# %% [markdown]
# ### Setting Hyperparameters

# %%
"""
Hyperparameter optimization in assignment 4(a), 4(b) can be 
conducted here.
Be sure to leave only your best hyperparameter combination
here and comment the original hyperparameter settings.
"""

# Setting some hyperparameters
TRAIN_BATCH_SIZE = 256
VAL_BATCH_SIZE = 200
INITIAL_LR = 0.01
MOMENTUM = 0.9
REG = 5e-4
EPOCHS = 100
DATAROOT = "./data"
CHECKPOINT_PATH = "./saved_model"

# %%
"""
Assignment 2(b)
Write functions to load dataset and preprocess the incoming data. 
We recommend that the preprocess scheme \textbf{must} include 
normalize, standardization, batch shuffling to make sure the training 
process goes smoothly. 
The preprocess scheme may also contain some data augmentation methods 
(e.g., random crop, random flip, etc.). 

Reference value for mean/std:

mean(RGB-format): (0.4914, 0.4822, 0.4465)
std(RGB-format): (0.2023, 0.1994, 0.2010)


NOTE: Considering this process has strong corrlelation with assignment 3(b), 
please leave the data preprocessing method which can achieve the highest 
validation accuracy here. You can include your original data augmentation
method as comments and denotes the accuracy difference between these two 
methods.
"""
# Specify preprocessing function.
# Reference mean/std value
mean_RGB = (0.4914, 0.4822, 0.4465)
std_RGB = (0.2023, 0.1994, 0.2010)
input_img_size = (32,32)
percent_crop = 0.80 # 80 percent left after crop
data_augment_list = [#transforms.RandomResizedCrop(size = input_img_size, scale=(percent_crop, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=2),
                     transforms.RandomVerticalFlip(p = 0.10),
                     transforms.RandomHorizontalFlip(p = 0.25),
                     transforms.RandomApply([transforms.RandomCrop(size = input_img_size, padding=4, pad_if_needed=False, fill=0, padding_mode='constant')], p = 0.15),
                     transforms.RandomApply([transforms.RandomAffine(degrees = 30, translate=(0.15,0.15), scale=None, shear=None, resample=False, fillcolor=0)], p = 0.15),
                     transforms.RandomApply([transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.05)], p = 0.10)]
transform_train = transforms.Compose([transforms.Resize(input_img_size),
                                      transforms.RandomOrder(data_augment_list),
                                      transforms.ToTensor(),
                                      transforms.RandomErasing(p=0.10, scale=(0.01, 0.15), ratio=(0.3, 3.3), value=0, inplace=False),
                                      transforms.Normalize(mean_RGB, std_RGB)])
transform_val = transforms.Compose([transforms.Resize(input_img_size),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean_RGB, std_RGB)])

# %%
# Call the dataset Loader
num_threads = 16
trainset = CIFAR10(root=DATAROOT, train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=num_threads//2)
valset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
valloader = torch.utils.data.DataLoader(valset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=num_threads//2)
# Out:
# Using downloaded and verified file: ./data\cifar10_trainval.tar.gz
# Extracting ./data\cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data\cifar10_trainval.tar.gz
# Extracting ./data\cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = TONY_NET()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %%
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = True
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# Training from scratch ...
# Starting from learning rate 0.010000:

# %%
"""
Assignment 2(c)
In the targeted classification task, we use cross entropy loss with L2 
regularization as the learning object.
You need to formulate the cross-entropy loss function in PyTorch.
You should also specify a PyTorch Optimizer to optimize this loss function.
We recommend you to use the SGD-momentum with an initial learning rate 0.01 
and momentum 0.9 as a start.
"""
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(net.parameters(), INITIAL_LR, MOMENTUM, weight_decay=REG, nesterov = True)

# %%
"""
Assignment 3(a)
Start the training process over the whole CIFAR-10 training dataset. 
For sanity check, you are required to report the initial loss value at 
the beginning of the training process and briefly justify this value. 
Run the training process for \textbf{a maximum of 30} epochs and you 
should be able to reach around \textbf{65\%} accuracy on the validation 
dataset.
"""
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
global_step = 0
best_val_acc = 0

for i in range(start_epoch, EPOCHS):
    print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    # Train the training dataset for 1 epoch.
    print(len(trainloader))
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        # Now backward loss
        loss.backward()
        # Apply gradient
        optimizer.step()
        # Calculate predicted labels
        _, predicted = torch.max(outputs.data, 1)
        # Calculate accuracy
        total_examples += targets.size(0)
        correct_examples += predicted.eq(targets.data).sum().item()
        train_loss += loss.data.item()

        global_step += 1
        if global_step % 100 == 0:
            avg_loss = train_loss / (batch_idx + 1)
        pass
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f %%" %(avg_loss, avg_acc*100))
    print(datetime.datetime.now())
    # Validate on the validation dataset
    print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            # Calculate predicted labels
            _, predicted = torch.max(outputs.data, 1)
            # Calculate accuracy
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets.data).sum().item()
            val_loss += loss.data.item()

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f %%" %(avg_loss, avg_acc*100))

        
    """
    Assignment 4(b)
    Learning rate is an important hyperparameter to tune. Specify a 
    learning rate decay policy and apply it in your training process. 
    Briefly describe its impact on the learning curveduring your 
    training process.    
    Reference learning rate schedule: 
    decay 0.98 for every 2 epochs. You may tune this parameter but 
    minimal gain will be achieved.
    Assignment 4(c)
    As we can see from above, hyperparameter optimization is critical 
    to obtain a good performance of DNN models. Try to fine-tune the 
    model to over 70% accuracy. You may also increase the number of 
    epochs to up to 100 during the process. Briefly describe what you 
    have tried to improve the performance of the LeNet-5 model.
    """
    DECAY_EPOCHS = 2
    DECAY = 0.98#0.98
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = INITIAL_LR*(DECAY**i)
        for param_group in optimizer.param_groups:
            # Assign the learning rate parameter
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %(current_learning_rate*(DECAY**i)))
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
# Out:
# 2019-10-01 14:00:55.997011
# Epoch 0:
# 176
# Training loss: 1.6994, Training accuracy: 42.2178 %
# 2019-10-01 14:01:07.244682
# Validation...
# Validation loss: 1.2139, Validation accuracy: 55.7800 %
# Saving ...
# 2019-10-01 14:01:12.714706
# Epoch 1:
# 176
# Training loss: 1.3144, Training accuracy: 53.5733 %
# 2019-10-01 14:01:24.046741
# Validation...
# Validation loss: 1.0045, Validation accuracy: 63.8000 %
# Saving ...
# 2019-10-01 14:01:29.578779
# Epoch 2:
# 176
# Training loss: 1.1734, Training accuracy: 58.4689 %
# 2019-10-01 14:01:40.763339
# Validation...
# Validation loss: 0.9140, Validation accuracy: 67.2800 %
# Current learning rate has decayed to 0.009224
# Saving ...
# 2019-10-01 14:01:46.294205
# Epoch 3:
# 176
# Training loss: 1.0879, Training accuracy: 61.4556 %
# 2019-10-01 14:01:57.477283
# Validation...
# Validation loss: 0.8457, Validation accuracy: 70.4600 %
# Saving ...
# 2019-10-01 14:02:02.990283
# Epoch 4:
# 176
# Training loss: 1.0436, Training accuracy: 63.0711 %
# 2019-10-01 14:02:14.138312
# Validation...
# Validation loss: 0.8051, Validation accuracy: 71.4400 %
# Current learning rate has decayed to 0.008508
# Saving ...
# 2019-10-01 14:02:19.643582
# Epoch 5:
# 176
# Training loss: 1.0026, Training accuracy: 64.7733 %
# 2019-10-01 14:02:30.800173
# Validation...
# Validation loss: 0.7729, Validation accuracy: 72.4400 %
# Saving ...
# 2019-10-01 14:02:36.291181
# Epoch 6:
# 176
# Training loss: 0.9785, Training accuracy: 65.6178 %
# 2019-10-01 14:02:47.493182
# Validation...
# Validation loss: 0.7643, Validation accuracy: 72.8800 %
# Current learning rate has decayed to 0.007847
# Saving ...
# 2019-10-01 14:02:52.930203
# Epoch 7:
# 176
# Training loss: 0.9492, Training accuracy: 66.4533 %
# 2019-10-01 14:03:04.071239
# Validation...
# Validation loss: 0.7354, Validation accuracy: 73.4000 %
# Saving ...
# 2019-10-01 14:03:09.551239
# Epoch 8:
# 176
# Training loss: 0.9316, Training accuracy: 67.2489 %
# 2019-10-01 14:03:20.756239
# Validation...
# Validation loss: 0.7334, Validation accuracy: 73.9600 %
# Current learning rate has decayed to 0.007238
# Saving ...
# 2019-10-01 14:03:26.179260
# Epoch 9:
# 176
# Training loss: 0.8997, Training accuracy: 68.2356 %
# 2019-10-01 14:03:37.307287
# Validation...
# Validation loss: 0.7161, Validation accuracy: 74.3600 %
# Saving ...
# 2019-10-01 14:03:42.719285
# Epoch 10:
# 176
# Training loss: 0.8842, Training accuracy: 68.8022 %
# 2019-10-01 14:03:53.869803
# Validation...
# Validation loss: 0.6789, Validation accuracy: 75.9400 %
# Current learning rate has decayed to 0.006676
# Saving ...
# 2019-10-01 14:04:00.519234
# Epoch 11:
# 176
# Training loss: 0.8616, Training accuracy: 69.6867 %
# Validation loss: 0.5444, Validation accuracy: 80.4800 %
# Saving ...
# 2019-10-01 14:07:36.596703
# Epoch 24:
# 176
# Training loss: 0.7080, Training accuracy: 75.2689 %
# 2019-10-01 14:07:47.856703
# Validation...
# Validation loss: 0.5756, Validation accuracy: 79.9200 %
# Current learning rate has decayed to 0.003792
# 2019-10-01 14:07:53.087728
# Epoch 25:
# 176
# Training loss: 0.7033, Training accuracy: 75.2756 %
# 2019-10-01 14:08:04.324788
# Validation...
# Validation loss: 0.5829, Validation accuracy: 78.8600 %
# 2019-10-01 14:08:09.622787
# Epoch 26:
# 176
# Training loss: 0.6965, Training accuracy: 75.5000 %
# 2019-10-01 14:08:20.823834
# Validation...
# Validation loss: 0.5505, Validation accuracy: 80.6800 %
# Current learning rate has decayed to 0.003497
# Saving ...
# 2019-10-01 14:08:26.579452
# Epoch 27:
# 176
# Training loss: 0.6868, Training accuracy: 75.8644 %
# 2019-10-01 14:08:37.712533
# Validation...
# Validation loss: 0.5710, Validation accuracy: 79.3800 %
# 2019-10-01 14:08:43.106542
# Epoch 28:
# 176
# Training loss: 0.6841, Training accuracy: 75.8400 %
# 2019-10-01 14:08:54.221564
# Validation...
# Validation loss: 0.5462, Validation accuracy: 81.3000 %
# Current learning rate has decayed to 0.003226
# Saving ...
# 2019-10-01 14:08:59.663683
# Epoch 29:
# 176
# Training loss: 0.6753, Training accuracy: 76.3822 %
# 2019-10-01 14:09:10.834683
# Validation...
# Validation loss: 0.5352, Validation accuracy: 81.1800 %
# 2019-10-01 14:09:16.149735
# Epoch 30:
# 176
# Training loss: 0.6621, Training accuracy: 76.8289 %
# 2019-10-01 14:09:27.284814
# Validation...
# Validation loss: 0.5248, Validation accuracy: 81.4600 %
# Current learning rate has decayed to 0.002976
# Saving ...
# 2019-10-01 14:09:32.800813
# Epoch 31:
# 176
# Training loss: 0.6629, Training accuracy: 76.9133 %
# 2019-10-01 14:09:43.963814
# Validation...
# Validation loss: 0.5476, Validation accuracy: 80.8600 %
# 2019-10-01 14:09:49.237815
# Epoch 32:
# 176
# Training loss: 0.6548, Training accuracy: 77.2156 %
# 2019-10-01 14:10:00.365813
# Validation...
# Validation loss: 0.5207, Validation accuracy: 82.0800 %
# Current learning rate has decayed to 0.002745
# Saving ...
# 2019-10-01 14:10:05.875812
# Epoch 33:
# 176
# Training loss: 0.6409, Training accuracy: 77.5778 %
# 2019-10-01 14:10:17.042365
# Validation...
# Validation loss: 0.5299, Validation accuracy: 81.2000 %
# 2019-10-01 14:10:22.300365
# Epoch 34:
# 176
# Training loss: 0.6365, Training accuracy: 77.5711 %
# 2019-10-01 14:10:33.486366
# Validation...
# Validation loss: 0.5120, Validation accuracy: 81.7200 %
# Current learning rate has decayed to 0.002531
# 2019-10-01 14:10:38.703880
# Epoch 35:
# 176
# Training loss: 0.6360, Training accuracy: 77.9800 %
# 2019-10-01 14:10:49.881878
# Validation...
# Validation loss: 0.5058, Validation accuracy: 82.3800 %
# Saving ...
# 2019-10-01 14:10:55.317886
# Validation...
# Validation loss: 0.4803, Validation accuracy: 83.1000 %
# Current learning rate has decayed to 0.001438
# 2019-10-01 14:14:33.050373
# Epoch 49:
# 176
# Training loss: 0.5647, Training accuracy: 80.3689 %
# 2019-10-01 14:14:44.218367
# Validation...
# Validation loss: 0.4905, Validation accuracy: 82.8200 %
# 2019-10-01 14:14:49.478905
# Epoch 50:
# 176
# Training loss: 0.5504, Training accuracy: 80.6956 %
# 2019-10-01 14:15:00.742949
# Validation...
# Validation loss: 0.4637, Validation accuracy: 83.6200 %
# Current learning rate has decayed to 0.001326
# Saving ...
# 2019-10-01 14:15:06.318949
# Epoch 51:
# 176
# Training loss: 0.5575, Training accuracy: 80.6422 %
# 2019-10-01 14:15:17.483950
# Validation...
# Validation loss: 0.4689, Validation accuracy: 83.3600 %
# 2019-10-01 14:15:22.774114
# Epoch 52:
# 176
# Training loss: 0.5541, Training accuracy: 80.7911 %
# 2019-10-01 14:15:33.928691
# Validation...
# Validation loss: 0.4714, Validation accuracy: 83.4400 %
# Current learning rate has decayed to 0.001223
# 2019-10-01 14:15:39.172691
# Epoch 53:
# 176
# Training loss: 0.5475, Training accuracy: 80.9489 %
# 2019-10-01 14:15:50.315782
# Validation...
# Validation loss: 0.4997, Validation accuracy: 82.5800 %
# 2019-10-01 14:15:55.643409
# Epoch 54:
# 176
# Training loss: 0.5487, Training accuracy: 80.7133 %
# 2019-10-01 14:16:06.836437
# Validation...
# Validation loss: 0.4887, Validation accuracy: 82.7000 %
# Current learning rate has decayed to 0.001128
# 2019-10-01 14:16:12.085694
# Epoch 55:
# 176
# Training loss: 0.5347, Training accuracy: 81.1711 %
# 2019-10-01 14:16:23.278752
# Validation...
# Validation loss: 0.4686, Validation accuracy: 83.6800 %
# Saving ...
# 2019-10-01 14:16:28.778749
# Epoch 56:
# 176
# Training loss: 0.5262, Training accuracy: 81.5333 %
# 2019-10-01 14:16:39.944775
# Validation...
# Validation loss: 0.4765, Validation accuracy: 83.1800 %
# Current learning rate has decayed to 0.001041
# 2019-10-01 14:16:45.158774
# Epoch 57:
# 176
# Training loss: 0.5359, Training accuracy: 81.3089 %
# 2019-10-01 14:16:56.332317
# Validation...
# Validation loss: 0.4605, Validation accuracy: 83.6600 %
# 2019-10-01 14:17:01.586450
# Epoch 58:
# 176
# Training loss: 0.5260, Training accuracy: 81.6956 %
# 2019-10-01 14:17:12.771452
# Validation...
# Validation loss: 0.4605, Validation accuracy: 84.1800 %
# Current learning rate has decayed to 0.000960
# Saving ...
# 2019-10-01 14:17:18.261701
# Epoch 59:
# 176
# Training loss: 0.5196, Training accuracy: 81.5978 %
# 2019-10-01 14:17:29.423730
# Validation...
# Validation loss: 0.4606, Validation accuracy: 83.8200 %
# 2019-10-01 14:17:34.601728
# Epoch 60:
# 176
# Training loss: 0.5238, Training accuracy: 81.8667 %
# 2019-10-01 14:17:45.752729
# Validation...
# Validation loss: 0.4499, Validation accuracy: 84.1800 %
# Current learning rate has decayed to 0.000885
# 2019-10-01 14:17:51.000729
# Current learning rate has decayed to 0.000191
# 2019-10-01 14:28:16.837177
# Epoch 99:
# 176
# Training loss: 0.4261, Training accuracy: 85.5622 %
# 2019-10-01 14:28:27.974227
# Validation...
# Validation loss: 0.4216, Validation accuracy: 85.6800 %
# Saving ...
# 2019-10-01 14:28:33.371986
# Epoch 100:
# 176
# Training loss: 0.4277, Training accuracy: 85.1378 %
# 2019-10-01 14:28:44.531316
# Validation...
# Validation loss: 0.4283, Validation accuracy: 84.8000 %
# Current learning rate has decayed to 0.000176
# 2019-10-01 14:28:49.714316
# Epoch 101:
# 176
# Training loss: 0.4226, Training accuracy: 85.3667 %
# 2019-10-01 14:29:00.904051
# Validation...
# Validation loss: 0.4281, Validation accuracy: 85.1600 %
# 2019-10-01 14:29:06.124051
# Epoch 102:
# 176
# Training loss: 0.4155, Training accuracy: 85.8089 %
# 2019-10-01 14:29:17.338051
# Validation...
# Validation loss: 0.4239, Validation accuracy: 85.3600 %
# Current learning rate has decayed to 0.000162
# 2019-10-01 14:29:22.541052
# Epoch 103:
# 176
# Training loss: 0.4251, Training accuracy: 85.4956 %
# 2019-10-01 14:29:33.683075
# Validation...
# Validation loss: 0.4116, Validation accuracy: 85.9200 %
# Saving ...
# 2019-10-01 14:29:39.111487
# Epoch 104:
# 176
# Training loss: 0.4267, Training accuracy: 85.4000 %
# 2019-10-01 14:29:50.283516
# Validation...
# Validation loss: 0.4159, Validation accuracy: 85.5200 %
# Current learning rate has decayed to 0.000150
# 2019-10-01 14:29:55.495516
# Epoch 105:
# 176
# Training loss: 0.4239, Training accuracy: 85.7667 %
# 2019-10-01 14:30:06.891088
# Validation...
# Validation loss: 0.4132, Validation accuracy: 85.4000 %
# 2019-10-01 14:30:12.133088
# Epoch 106:
# 176
# Training loss: 0.4129, Training accuracy: 86.0600 %
# 2019-10-01 14:30:23.495089
# Validation...
# Validation loss: 0.4117, Validation accuracy: 85.8000 %
# Current learning rate has decayed to 0.000138
# 2019-10-01 14:30:28.749089
# Epoch 107:
# 176
# Training loss: 0.4098, Training accuracy: 85.9867 %
# 2019-10-01 14:30:40.102655
# Validation...
# Validation loss: 0.4146, Validation accuracy: 85.9000 %
# 2019-10-01 14:30:45.306655
# Epoch 108:
# 176
# Training loss: 0.4160, Training accuracy: 85.8667 %
# 2019-10-01 14:30:56.534679
# Validation...
# Validation loss: 0.4190, Validation accuracy: 85.6000 %
# Current learning rate has decayed to 0.000127
# 2019-10-01 14:31:01.782680
# Epoch 109:
# 176
# Training loss: 0.4114, Training accuracy: 86.1511 %
# 2019-10-01 14:31:13.018706
# Validation...
# Validation loss: 0.4087, Validation accuracy: 86.1600 %
# Saving ...
# 2019-10-01 14:31:18.399704
# Epoch 110:
# 176
# Training loss: 0.4073, Training accuracy: 85.9289 %
# 2019-10-01 14:31:29.639083
# Validation...
# Validation loss: 0.4140, Validation accuracy: 85.7800 %
# Current learning rate has decayed to 0.000117
# 2019-10-01 14:31:34.835081
# Epoch 111:
# 176
# Training loss: 0.4036, Training accuracy: 86.3889 %
# 2019-10-01 14:31:46.124603
# Validation...
# Validation loss: 0.4182, Validation accuracy: 85.7200 %
# 2019-10-01 14:31:51.322602
# Epoch 112:
# 176
# Training loss: 0.4036, Training accuracy: 86.2689 %
# 2019-10-01 14:32:02.534603
# Validation...
# Validation loss: 0.4144, Validation accuracy: 85.6800 %
# Current learning rate has decayed to 0.000108
# 2019-10-01 14:32:07.710603
# Epoch 113:
# 176
# Training loss: 0.4094, Training accuracy: 86.0978 %
# 2019-10-01 14:32:18.923604
# Validation...
# Validation loss: 0.4132, Validation accuracy: 85.9200 %
# 2019-10-01 14:32:24.117602
# Epoch 114:
# 176
# Training loss: 0.4007, Training accuracy: 86.5244 %
# 2019-10-01 14:32:35.296116
# Validation...
# Validation loss: 0.4183, Validation accuracy: 85.7600 %
# Current learning rate has decayed to 0.000100
# 2019-10-01 14:32:40.531118
# Epoch 115:
# 176
# Training loss: 0.4046, Training accuracy: 86.1667 %
# 2019-10-01 14:32:51.802116
# Validation...
# Validation loss: 0.4148, Validation accuracy: 85.8200 %
# 2019-10-01 14:32:57.025118
# Epoch 116:
# 176
# Training loss: 0.4065, Training accuracy: 86.2111 %
# 2019-10-01 14:33:08.161142
# Validation...
# Validation loss: 0.4204, Validation accuracy: 85.6000 %
# Current learning rate has decayed to 0.000092
# 2019-10-01 14:33:13.524142
# Epoch 117:
# 176
# Training loss: 0.4079, Training accuracy: 86.1156 %
# 2019-10-01 14:33:24.693391
# Validation...
# Validation loss: 0.4199, Validation accuracy: 85.6800 %
# 2019-10-01 14:33:30.087391
# Epoch 118:
# 176
# Training loss: 0.3993, Training accuracy: 86.5889 %
# 2019-10-01 14:33:41.218477
# Validation...
# Validation loss: 0.4184, Validation accuracy: 85.8200 %
# Current learning rate has decayed to 0.000085
# 2019-10-01 14:33:46.525478
# Epoch 119:
# 176
# Training loss: 0.4056, Training accuracy: 86.3422 %
# 2019-10-01 14:33:57.683478
# Validation...
# Validation loss: 0.4124, Validation accuracy: 85.9200 %
# 2019-10-01 14:34:02.987036
# Epoch 120:
# 176
# Training loss: 0.3962, Training accuracy: 86.3422 %
# 2019-10-01 14:34:14.169698
# Validation...
# Validation loss: 0.4070, Validation accuracy: 85.9200 %
# Current learning rate has decayed to 0.000078
# 2019-10-01 14:34:19.478697
# Epoch 121:
# 176
# Training loss: 0.4040, Training accuracy: 86.3733 %
# 2019-10-01 14:34:30.653699
# Validation...
# Validation loss: 0.4119, Validation accuracy: 85.6400 %
# 2019-10-01 14:34:35.871697
# Epoch 122:
# 176
# Training loss: 0.3903, Training accuracy: 86.7289 %
# 2019-10-01 14:34:47.024698
# Validation...
# Validation loss: 0.4108, Validation accuracy: 85.7800 %
# Current learning rate has decayed to 0.000072
# 2019-10-01 14:34:52.331720
# Epoch 123:
# 176
# Training loss: 0.3953, Training accuracy: 86.6822 %
# 2019-10-01 14:35:03.481719
# Validation...
# Validation loss: 0.4140, Validation accuracy: 86.1000 %
# 2019-10-01 14:35:08.865735
# Epoch 124:
# 176
# Training loss: 0.3990, Training accuracy: 86.4800 %
# 2019-10-01 14:35:20.036779
# Validation...
# Validation loss: 0.4112, Validation accuracy: 85.9800 %
# Current learning rate has decayed to 0.000067
# 2019-10-01 14:35:25.376521
# Epoch 125:
# 176
# Training loss: 0.3836, Training accuracy: 86.8111 %
# 2019-10-01 14:35:36.555571
# Validation...
# Validation loss: 0.4139, Validation accuracy: 86.2000 %
# Saving ...
# 2019-10-01 14:35:42.045625
# Epoch 126:
# 176
# Training loss: 0.3863, Training accuracy: 86.9956 %
# 2019-10-01 14:35:53.195733
# Validation...
# Validation loss: 0.4143, Validation accuracy: 85.5200 %
# Current learning rate has decayed to 0.000062
# 2019-10-01 14:35:58.398735
# Epoch 127:
# 176
# Training loss: 0.3931, Training accuracy: 86.8467 %
# 2019-10-01 14:36:09.642735
# Validation...
# Validation loss: 0.4098, Validation accuracy: 86.3200 %
# Saving ...
# 2019-10-01 14:36:15.020731
# Epoch 128:
# 176
# Training loss: 0.3904, Training accuracy: 86.8422 %
# 2019-10-01 14:36:26.225858
# Validation...
# Validation loss: 0.4089, Validation accuracy: 86.0600 %
# Current learning rate has decayed to 0.000057
# 2019-10-01 14:36:31.399857
# Epoch 129:
# 176
# Training loss: 0.3771, Training accuracy: 87.1311 %
# 2019-10-01 14:36:42.545857
# Validation...
# Validation loss: 0.4120, Validation accuracy: 85.3600 %
# 2019-10-01 14:36:47.780857
# Epoch 130:
# 176
# Training loss: 0.3840, Training accuracy: 87.0356 %
# 2019-10-01 14:36:58.945856
# Validation...
# Validation loss: 0.4022, Validation accuracy: 86.2600 %
# Current learning rate has decayed to 0.000052
# 2019-10-01 14:37:04.118911
# Epoch 131:
# 176
# Training loss: 0.3863, Training accuracy: 87.0889 %
# 2019-10-01 14:37:15.301942
# Validation...
# Validation loss: 0.4071, Validation accuracy: 86.2600 %
# 2019-10-01 14:37:20.474970
# Epoch 132:
# 176
# Training loss: 0.3780, Training accuracy: 87.5133 %
# 2019-10-01 14:37:31.666887
# Validation...
# Validation loss: 0.4069, Validation accuracy: 86.1000 %
# Current learning rate has decayed to 0.000048
# 2019-10-01 14:37:36.857888
# Epoch 133:
# 176
# Training loss: 0.3858, Training accuracy: 86.9267 %
# 2019-10-01 14:37:48.018890
# Validation...
# Validation loss: 0.4077, Validation accuracy: 86.0800 %
# 2019-10-01 14:37:53.168886
# Epoch 134:
# 176
# Training loss: 0.3768, Training accuracy: 87.2178 %
# 2019-10-01 14:38:04.328887
# Validation...
# Validation loss: 0.4067, Validation accuracy: 86.0200 %
# Current learning rate has decayed to 0.000045
# 2019-10-01 14:38:09.504886
# Epoch 135:
# 176
# Training loss: 0.3778, Training accuracy: 87.1956 %
# 2019-10-01 14:38:20.703889
# Validation...
# Validation loss: 0.4052, Validation accuracy: 86.4600 %
# Saving ...
# 2019-10-01 14:38:26.141147
# Epoch 136:
# 176
# Training loss: 0.3809, Training accuracy: 87.2356 %
# 2019-10-01 14:38:37.297177
# Validation...
# Validation loss: 0.4083, Validation accuracy: 86.2400 %
# Current learning rate has decayed to 0.000041
# 2019-10-01 14:38:42.454694
# Epoch 137:
# 176
# Training loss: 0.3783, Training accuracy: 87.0911 %
# 2019-10-01 14:38:53.654370
# Validation...
# Validation loss: 0.4090, Validation accuracy: 85.8800 %
# 2019-10-01 14:38:58.837370
# Epoch 138:
# 176
# Training loss: 0.3796, Training accuracy: 87.2978 %
# 2019-10-01 14:39:10.016368
# Validation...
# Validation loss: 0.4082, Validation accuracy: 85.8000 %
# Current learning rate has decayed to 0.000038
# 2019-10-01 14:39:15.201882
# Epoch 139:
# 176
# Training loss: 0.3810, Training accuracy: 87.3533 %
# 2019-10-01 14:39:26.476883
# Validation...
# Validation loss: 0.4119, Validation accuracy: 85.7800 %
# 2019-10-01 14:39:31.697882
# Epoch 140:
# 176
# Training loss: 0.3764, Training accuracy: 87.2556 %
# 2019-10-01 14:39:42.982657
# Validation...
# Validation loss: 0.4126, Validation accuracy: 85.7200 %
# Current learning rate has decayed to 0.000035
# 2019-10-01 14:39:48.199657
# Epoch 141:
# 176
# Training loss: 0.3670, Training accuracy: 87.3444 %
# 2019-10-01 14:39:59.453658
# Validation...
# Validation loss: 0.4077, Validation accuracy: 86.0000 %
# 2019-10-01 14:40:04.683686
# Epoch 142:
# 176
# Training loss: 0.3690, Training accuracy: 87.4667 %
# 2019-10-01 14:40:15.928747
# Validation...
# Validation loss: 0.4094, Validation accuracy: 85.9400 %
# Current learning rate has decayed to 0.000032
# 2019-10-01 14:40:21.145749
# Epoch 143:
# 176
# Training loss: 0.3714, Training accuracy: 87.3200 %
# 2019-10-01 14:40:32.429597
# Validation...
# Validation loss: 0.4098, Validation accuracy: 85.6800 %
# 2019-10-01 14:40:37.652835
# Epoch 144:
# 176
# Training loss: 0.3767, Training accuracy: 87.3667 %
# 2019-10-01 14:40:48.894835
# Validation...
# Validation loss: 0.4068, Validation accuracy: 86.2200 %
# Current learning rate has decayed to 0.000030
# 2019-10-01 14:40:54.103835
# Epoch 145:
# 176
# Training loss: 0.3729, Training accuracy: 87.4778 %
# 2019-10-01 14:41:05.719420
# Validation...
# Validation loss: 0.4095, Validation accuracy: 86.1600 %
# 2019-10-01 14:41:10.950421
# Epoch 146:
# 176
# Training loss: 0.3759, Training accuracy: 87.4533 %
# 2019-10-01 14:41:22.237420
# Validation...
# Validation loss: 0.4131, Validation accuracy: 85.7400 %
# Current learning rate has decayed to 0.000027
# 2019-10-01 14:41:27.449420
# Epoch 147:
# 176
# Training loss: 0.3705, Training accuracy: 87.7644 %
# 2019-10-01 14:41:38.712420
# Validation...
# Validation loss: 0.4065, Validation accuracy: 86.1200 %
# 2019-10-01 14:41:43.948423
# Epoch 148:
# 176
# Training loss: 0.3621, Training accuracy: 87.8533 %
# 2019-10-01 14:41:55.247421
# Validation...
# Validation loss: 0.4040, Validation accuracy: 86.0600 %
# Current learning rate has decayed to 0.000025
# 2019-10-01 14:42:00.460428
# Epoch 149:
# 176
# Training loss: 0.3577, Training accuracy: 87.8644 %
# 2019-10-01 14:42:11.660568
# Validation...
# Validation loss: 0.4061, Validation accuracy: 86.3000 %
# 2019-10-01 14:42:16.884567
# Epoch 150:
# 176
# Training loss: 0.3654, Training accuracy: 87.6822 %
# 2019-10-01 14:42:28.070567
# Validation...
# Validation loss: 0.4071, Validation accuracy: 86.2600 %
# Current learning rate has decayed to 0.000023
# 2019-10-01 14:42:33.381566
# Epoch 151:
# 176
# Training loss: 0.3655, Training accuracy: 87.6244 %
# 2019-10-01 14:42:44.544567
# Validation...
# Validation loss: 0.4053, Validation accuracy: 85.9200 %
# 2019-10-01 14:42:49.768568
# Epoch 152:
# 176
# Training loss: 0.3660, Training accuracy: 87.7600 %
# 2019-10-01 14:43:00.933567
# Validation...
# Validation loss: 0.4070, Validation accuracy: 86.0400 %
# Current learning rate has decayed to 0.000022
# 2019-10-01 14:43:06.334621
# Epoch 153:
# 176
# Training loss: 0.3661, Training accuracy: 87.6533 %
# 2019-10-01 14:43:17.506157
# Validation...
# Validation loss: 0.4052, Validation accuracy: 86.1400 %
# 2019-10-01 14:43:22.753157
# Epoch 154:
# 176
# Training loss: 0.3706, Training accuracy: 87.5956 %
# 2019-10-01 14:43:33.902159
# Validation...
# Validation loss: 0.4048, Validation accuracy: 86.2600 %
# Current learning rate has decayed to 0.000020
# 2019-10-01 14:43:39.319969
# Epoch 155:
# 176
# Training loss: 0.3679, Training accuracy: 87.6533 %
# 2019-10-01 14:43:50.472999
# Validation...
# Validation loss: 0.4057, Validation accuracy: 86.1800 %
# 2019-10-01 14:43:55.746229
# Epoch 156:
# 176
# Training loss: 0.3602, Training accuracy: 87.8867 %
# 2019-10-01 14:44:06.928821
# Validation...
# Validation loss: 0.4026, Validation accuracy: 86.2600 %
# Current learning rate has decayed to 0.000018
# 2019-10-01 14:44:12.206820
# Epoch 157:
# 176
# Training loss: 0.3594, Training accuracy: 88.0244 %
# 2019-10-01 14:44:23.360820
# Validation...
# Validation loss: 0.4100, Validation accuracy: 86.1000 %
# 2019-10-01 14:44:28.660821
# Epoch 158:
# 176
# Training loss: 0.3541, Training accuracy: 88.3022 %
# 2019-10-01 14:44:39.795819
# Validation...
# Validation loss: 0.4055, Validation accuracy: 86.1600 %
# Current learning rate has decayed to 0.000017
# 2019-10-01 14:44:45.105821
# Epoch 159:
# 176
# Training loss: 0.3620, Training accuracy: 87.8533 %
# 2019-10-01 14:44:56.277821
# Validation...
# Validation loss: 0.4049, Validation accuracy: 85.9400 %
# 2019-10-01 14:45:01.636576
# Epoch 160:
# 176
# Training loss: 0.3540, Training accuracy: 88.2511 %
# 2019-10-01 14:45:12.897274
# Validation...
# Validation loss: 0.4041, Validation accuracy: 86.4800 %
# Current learning rate has decayed to 0.000016
# Saving ...
# 2019-10-01 14:45:18.355271
# Epoch 161:
# 176
# Training loss: 0.3581, Training accuracy: 87.8378 %
# 2019-10-01 14:45:29.605274
# Validation...
# Validation loss: 0.4072, Validation accuracy: 86.3000 %
# 2019-10-01 14:45:34.800274
# Epoch 162:
# 176
# Training loss: 0.3559, Training accuracy: 88.0822 %
# 2019-10-01 14:45:45.997308
# Validation...
# Validation loss: 0.4035, Validation accuracy: 86.5800 %
# Current learning rate has decayed to 0.000014
# Saving ...
# 2019-10-01 14:45:51.454385
# Epoch 163:
# 176
# Training loss: 0.3553, Training accuracy: 88.2222 %
# 2019-10-01 14:46:02.699481
# Validation...
# Validation loss: 0.4008, Validation accuracy: 86.3800 %
# 2019-10-01 14:46:07.905479
# Epoch 164:
# 176
# Training loss: 0.3530, Training accuracy: 88.1844 %
# 2019-10-01 14:46:19.056512
# Validation...
# Validation loss: 0.4018, Validation accuracy: 86.3400 %
# Current learning rate has decayed to 0.000013
# 2019-10-01 14:46:24.250574
# Epoch 165:
# 176
# Training loss: 0.3607, Training accuracy: 88.0244 %
# 2019-10-01 14:46:35.476672
# Validation...
# Validation loss: 0.4021, Validation accuracy: 86.5400 %
# 2019-10-01 14:46:40.690736
# Epoch 166:
# 176
# Training loss: 0.3473, Training accuracy: 88.1667 %
# 2019-10-01 14:46:51.919868
# Validation...
# Validation loss: 0.3966, Validation accuracy: 86.5000 %
# Current learning rate has decayed to 0.000012
# 2019-10-01 14:46:57.115004
# Epoch 167:
# 176
# Training loss: 0.3502, Training accuracy: 88.2089 %
# 2019-10-01 14:47:08.325003
# Validation...
# Validation loss: 0.3973, Validation accuracy: 86.2600 %
# 2019-10-01 14:47:13.523004
# Epoch 168:
# 176
# Training loss: 0.3605, Training accuracy: 88.1289 %
# 2019-10-01 14:47:24.711546
# Validation...
# Validation loss: 0.3987, Validation accuracy: 86.6800 %
# Current learning rate has decayed to 0.000011
# Saving ...
# 2019-10-01 14:47:30.101825
# Epoch 169:
# 176
# Training loss: 0.3546, Training accuracy: 88.1867 %
# 2019-10-01 14:47:41.286828
# Validation...
# Validation loss: 0.3937, Validation accuracy: 86.4800 %
# 2019-10-01 14:47:46.490826
# Epoch 170:
# 176
# Training loss: 0.3597, Training accuracy: 88.1489 %
# 2019-10-01 14:47:57.707826
# Validation...
# Validation loss: 0.3980, Validation accuracy: 86.5000 %
# Current learning rate has decayed to 0.000010
# 2019-10-01 14:48:02.877829
# Epoch 171:
# 176
# Training loss: 0.3534, Training accuracy: 88.0533 %
# 2019-10-01 14:48:14.115846
# Validation...
# Validation loss: 0.4039, Validation accuracy: 86.2600 %
# 2019-10-01 14:48:19.376847
# Epoch 172:
# 176
# Training loss: 0.3506, Training accuracy: 88.3933 %
# 2019-10-01 14:48:30.583846
# Validation...
# Validation loss: 0.3990, Validation accuracy: 86.4800 %
# Current learning rate has decayed to 0.000010
# 2019-10-01 14:48:35.781362
# Epoch 173:
# 176
# Training loss: 0.3508, Training accuracy: 88.2889 %
# 2019-10-01 14:48:46.972438
# Validation...
# Validation loss: 0.4003, Validation accuracy: 86.7600 %
# Saving ...
# 2019-10-01 14:48:52.421646
# Epoch 174:
# 176
# Training loss: 0.3514, Training accuracy: 88.2644 %
# 2019-10-01 14:49:03.648649
# Validation...
# Validation loss: 0.4021, Validation accuracy: 86.3200 %
# Current learning rate has decayed to 0.000009
# 2019-10-01 14:49:08.907650
# Epoch 175:
# 176
# Training loss: 0.3553, Training accuracy: 88.3200 %
# 2019-10-01 14:49:20.240647
# Validation...
# Validation loss: 0.3977, Validation accuracy: 86.7400 %
# 2019-10-01 14:49:25.454693
# Epoch 176:
# 176
# Training loss: 0.3502, Training accuracy: 88.3667 %
# 2019-10-01 14:49:36.813835
# Validation...
# Validation loss: 0.4003, Validation accuracy: 86.6000 %
# Current learning rate has decayed to 0.000008
# 2019-10-01 14:49:41.996901
# Epoch 177:
# 176
# Training loss: 0.3528, Training accuracy: 88.3333 %
# 2019-10-01 14:49:53.260902
# Validation...
# Validation loss: 0.3975, Validation accuracy: 86.6000 %
# 2019-10-01 14:49:58.501064
# Epoch 178:
# 176
# Training loss: 0.3534, Training accuracy: 88.0778 %
# 2019-10-01 14:50:09.756066
# Validation...
# Validation loss: 0.3993, Validation accuracy: 86.4800 %
# Current learning rate has decayed to 0.000008
# 2019-10-01 14:50:14.949066
# Epoch 179:
# 176
# Training loss: 0.3405, Training accuracy: 88.6622 %
# 2019-10-01 14:50:26.244243
# Validation...
# Validation loss: 0.4008, Validation accuracy: 86.2200 %
# 2019-10-01 14:50:31.484244
# Epoch 180:
# 176
# Training loss: 0.3474, Training accuracy: 88.1533 %
# 2019-10-01 14:50:42.752267
# Validation...
# Validation loss: 0.3996, Validation accuracy: 86.5400 %
# Current learning rate has decayed to 0.000007
# 2019-10-01 14:50:47.977269
# Epoch 181:
# 176
# Training loss: 0.3396, Training accuracy: 88.5289 %
# 2019-10-01 14:50:59.324452
# Validation...
# Validation loss: 0.3974, Validation accuracy: 86.5400 %
# 2019-10-01 14:51:04.583453
# Epoch 182:
# 176
# Training loss: 0.3439, Training accuracy: 88.6267 %
# 2019-10-01 14:51:15.839669
# Validation...
# Validation loss: 0.3949, Validation accuracy: 86.5000 %
# Current learning rate has decayed to 0.000006
# 2019-10-01 14:51:21.063669
# Epoch 183:
# 176
# Training loss: 0.3392, Training accuracy: 88.5422 %
# 2019-10-01 14:51:32.254574
# Validation...
# Validation loss: 0.3981, Validation accuracy: 86.7000 %
# 2019-10-01 14:51:37.589574
# Epoch 184:
# 176
# Training loss: 0.3450, Training accuracy: 88.4800 %
# 2019-10-01 14:51:48.762575
# Validation...
# Validation loss: 0.3983, Validation accuracy: 86.6800 %
# Current learning rate has decayed to 0.000006
# 2019-10-01 14:51:54.090575
# Epoch 185:
# 176
# Training loss: 0.3427, Training accuracy: 88.7644 %
# 2019-10-01 14:52:05.264575
# Validation...
# Validation loss: 0.3974, Validation accuracy: 86.4000 %
# 2019-10-01 14:52:10.675575
# Epoch 186:
# 176
# Training loss: 0.3360, Training accuracy: 88.9200 %
# 2019-10-01 14:52:21.810574
# Validation...
# Validation loss: 0.3957, Validation accuracy: 86.6000 %
# Current learning rate has decayed to 0.000005
# 2019-10-01 14:52:27.075574
# Epoch 187:
# 176
# Training loss: 0.3464, Training accuracy: 88.5333 %
# 2019-10-01 14:52:38.235623
# Validation...
# Validation loss: 0.3968, Validation accuracy: 86.8000 %
# Saving ...
# 2019-10-01 14:52:47.351717
# Epoch 188:
# 176
# Training loss: 0.3470, Training accuracy: 88.5289 %
# 2019-10-01 14:52:58.564741
# Validation...
# Validation loss: 0.4027, Validation accuracy: 86.1200 %
# Current learning rate has decayed to 0.000005
# 2019-10-01 14:53:03.761828
# Epoch 189:
# 176
# Training loss: 0.3373, Training accuracy: 88.8178 %
# 2019-10-01 14:53:14.921880
# Validation...
# Validation loss: 0.4017, Validation accuracy: 86.4000 %
# 2019-10-01 14:53:20.130880
# Epoch 190:
# 176
# Training loss: 0.3383, Training accuracy: 88.7289 %
# 2019-10-01 14:53:31.305882
# Validation...
# Validation loss: 0.4010, Validation accuracy: 86.3800 %
# Current learning rate has decayed to 0.000005
# 2019-10-01 14:53:36.488004
# Epoch 191:
# 176
# Training loss: 0.3434, Training accuracy: 88.5889 %
# 2019-10-01 14:53:47.646079
# Validation...
# Validation loss: 0.3972, Validation accuracy: 86.9000 %
# Saving ...
# 2019-10-01 14:53:53.040617
# Epoch 192:
# 176
# Training loss: 0.3409, Training accuracy: 88.7378 %
# 2019-10-01 14:54:04.188983
# Validation...
# Validation loss: 0.4017, Validation accuracy: 86.5200 %
# Current learning rate has decayed to 0.000004
# 2019-10-01 14:54:09.409983
# Epoch 193:
# 176
# Training loss: 0.3448, Training accuracy: 88.5333 %
# 2019-10-01 14:54:20.583982
# Validation...
# Validation loss: 0.3978, Validation accuracy: 86.8200 %
# 2019-10-01 14:54:25.803983
# Epoch 194:
# 176
# Training loss: 0.3377, Training accuracy: 88.8378 %
# 2019-10-01 14:54:36.948195
# Validation...
# Validation loss: 0.3997, Validation accuracy: 86.5200 %
# Current learning rate has decayed to 0.000004
# 2019-10-01 14:54:42.126196
# Epoch 195:
# 176
# Training loss: 0.3440, Training accuracy: 88.6844 %
# 2019-10-01 14:54:53.285194
# Validation...
# Validation loss: 0.3966, Validation accuracy: 86.8800 %
# 2019-10-01 14:54:58.480194
# Epoch 196:
# 176
# Training loss: 0.3419, Training accuracy: 88.7333 %
# 2019-10-01 14:55:09.666196
# Validation...
# Validation loss: 0.3966, Validation accuracy: 86.7200 %
# Current learning rate has decayed to 0.000004
# 2019-10-01 14:55:14.849195
# Epoch 197:
# 176
# Training loss: 0.3349, Training accuracy: 88.7511 %
# 2019-10-01 14:55:26.062196
# Validation...
# Validation loss: 0.3965, Validation accuracy: 86.7200 %
# 2019-10-01 14:55:31.275195
# Epoch 198:
# 176
# Training loss: 0.3393, Training accuracy: 88.6111 %
# 2019-10-01 14:55:42.459194
# Validation...
# Validation loss: 0.3981, Validation accuracy: 86.8600 %
# Current learning rate has decayed to 0.000003
# 2019-10-01 14:55:47.677195
# Epoch 199:
# 176
# Training loss: 0.3415, Training accuracy: 88.5156 %
# 2019-10-01 14:55:58.974196
# Validation...
# Validation loss: 0.3966, Validation accuracy: 86.6200 %
# Optimization finished.
