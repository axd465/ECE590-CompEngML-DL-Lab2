# %% [markdown]
# # ECE 590 - Lab2 - LeNet5 Cifar 10 - Anthony DiSpirito

# %% [markdown]
# ## My Info
# * **Name: Anthony DiSpirito**
# * **NetID: ad424**
# * **Class: ECE 590 - Comp Eng ML and DL**
# * **Title: Lab2 - LeNet5 Cifar10**
# * **Date: 10/2/19**

# %% [markdown]
# ## Build LeNet5 Model

# %% [markdown]
# ### Import Statements

# %%
import argparse
import os, sys
import math
import random
import time
import datetime

# Import pytorch dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import torch.backends.cudnn as cudnn
from tqdm import tqdm_notebook as tqdm

# You cannot change this line.
from tools.dataloader import CIFAR10

# %% [markdown]
# ### My Model Class

# %%
""" 
Assignment 2(a)
Build the LeNet-5 model by following table 1 or figure 1.

You can also insert batch normalization and leave the LeNet-5 
with batch normalization here for assignment 3(c).
"""
# Create the neural network module: LeNet-5
class MyModel(nn.Module):
    def __init__(self):
        '''
        FUNCTIONS USED IN THIS SECTION:
        -----------------------------------------
        Conv2d Function takes form:
        
        torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride=1,
                        padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros')
        -----------------------------------------
        BatchNorm2d Function takes the form:
        
        torch.nn.BatchNorm2d(num_features, eps=1e-05, momentum=0.1,
                             affine=True, track_running_stats=True)
        -----------------------------------------
        Linear Function:
        torch.nn.Linear(in_features, out_features, bias=True)
        '''
        super(MyModel, self).__init__()
        # Convolutional Layers
        self.conv1 = nn.Conv2d(3, 6, 5, padding=0, dilation=1,
                               groups=1, bias=True, padding_mode='zeros')
        self.bn_conv1 = nn.BatchNorm2d(6, eps=1e-05,momentum=0.1, 
                                       affine=True, track_running_stats=True)
        self.conv2 = nn.Conv2d(6, 16, 5, padding=0, dilation=1,
                               groups=1, bias=True, padding_mode='zeros')
        self.bn_conv2 = nn.BatchNorm2d(16, eps=1e-05, momentum=0.1,
                                       affine=True, track_running_stats=True)
        #______________________________
        # My Addition
        self.conv3 = nn.Conv2d(16, 32, 3, padding=0, dilation=1,
                               groups=1, bias=True, padding_mode='zeros')
        self.bn_conv3 = nn.BatchNorm2d(32, eps=1e-05, momentum=0.1,
                                       affine=True, track_running_stats=True)
        self.conv4 = nn.Conv2d(32, 64, 1, padding=0, dilation=1,
                               groups=1, bias=True, padding_mode='zeros')
        self.bn_conv4 = nn.BatchNorm2d(64, eps=1e-05, momentum=0.1,
                                       affine=True, track_running_stats=True)
        self.fc1 = nn.Linear(64*(5**2), 128, bias = True)
        self.fc2 = nn.Linear(128, 10, bias = True)
        #______________________________
        # Fully Connected Layers
        #self.fc1 = nn.Linear(16*(5**2), 120, bias = True)
        #self.fc2 = nn.Linear(120, 84, bias = True)     
        #self.fc3 = nn.Linear(84, 10, bias = True)
        return
    
    def forward(self, x):
        # First Convolutional Layer (ReLu activation)
        out = F.relu(self.bn_conv1(self.conv1(x)))
        # First Pooling Layer (2x2 strides and pooling size)
        
        # Second Convolutional Layer (ReLu activation)
        out = F.relu(self.bn_conv2(self.conv2(out)))
        # Second Pooling Layer (2x2 strides and pooling size)
        out = F.max_pool2d(out, 2)
        #______________________________
        # My Addition
        out = F.relu(self.bn_conv3(self.conv3(out)))
        out = F.relu(self.bn_conv4(self.conv4(out)))
        out = F.max_pool2d(out, 2)
        #______________________________
        # Reshapes "out" so we can input into Fully Connected Layer
        out = out.view(out.size(0), -1)
        # First Fully Connected Layer (ReLu activation)
        out = F.relu(self.fc1(out))
        # Second Fully Connected Layer (ReLu activation)
        out = self.fc2(out) #out = F.relu(self.fc2(out))
        # Third Fully Connected Layer (Softmax activation)
        #out = self.fc3(out)#F.softmax(self.fc3(out), dim=0)
        return out

# %% [markdown]
# ### Setting Hyperparameters

# %%
"""
Hyperparameter optimization in assignment 4(a), 4(b) can be 
conducted here.
Be sure to leave only your best hyperparameter combination
here and comment the original hyperparameter settings.
"""

# Setting some hyperparameters
TRAIN_BATCH_SIZE = 64#128
VAL_BATCH_SIZE = 50#100
INITIAL_LR = 0.01
MOMENTUM = 0.9
REG = 1e-4
EPOCHS = 100 #30
DATAROOT = "./data"
CHECKPOINT_PATH = "./saved_model"

# %%
"""
Assignment 2(b)
Write functions to load dataset and preprocess the incoming data. 
We recommend that the preprocess scheme \textbf{must} include 
normalize, standardization, batch shuffling to make sure the training 
process goes smoothly. 
The preprocess scheme may also contain some data augmentation methods 
(e.g., random crop, random flip, etc.). 

Reference value for mean/std:

mean(RGB-format): (0.4914, 0.4822, 0.4465)
std(RGB-format): (0.2023, 0.1994, 0.2010)


NOTE: Considering this process has strong corrlelation with assignment 3(b), 
please leave the data preprocessing method which can achieve the highest 
validation accuracy here. You can include your original data augmentation
method as comments and denotes the accuracy difference between these two 
methods.
"""
# Specify preprocessing function.
# Reference mean/std value
mean_RGB = (0.4914, 0.4822, 0.4465)
std_RGB = (0.2023, 0.1994, 0.2010)
input_img_size = (32,32)
percent_crop = 0.80 # 80 percent left after crop
data_augment_list = [#transforms.RandomResizedCrop(size = input_img_size, scale=(percent_crop, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=2),
                     transforms.RandomVerticalFlip(p = 0.10),
                     transforms.RandomHorizontalFlip(p = 0.15),
                     transforms.RandomApply([transforms.RandomCrop(size = input_img_size, padding=4, pad_if_needed=False, fill=0, padding_mode='constant')], p = 0.15),
                     transforms.RandomApply([transforms.RandomAffine(degrees = 45, translate=(0.15,0.15), scale=None, shear=None, resample=False, fillcolor=0)], p = 0.20),
                     transforms.RandomApply([transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.05)], p = 0.15)]
transform_train = transforms.Compose([transforms.Resize(input_img_size),
                                      transforms.RandomOrder(data_augment_list),
                                      transforms.ToTensor(),
                                      transforms.RandomErasing(p=0.10, scale=(0.01, 0.15), ratio=(0.3, 3.3), value=0, inplace=False),
                                      transforms.Normalize(mean_RGB, std_RGB)])
transform_val = transforms.Compose([transforms.Resize(input_img_size),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean_RGB, std_RGB)])

# %%
# Call the dataset Loader
num_threads = 16
trainset = CIFAR10(root=DATAROOT, train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=num_threads//2)
valset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
valloader = torch.utils.data.DataLoader(valset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=num_threads//2)
# Out:
# Using downloaded and verified file: ./data\cifar10_trainval.tar.gz
# Extracting ./data\cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data\cifar10_trainval.tar.gz
# Extracting ./data\cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = MyModel()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %%
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = True
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# Training from scratch ...
# Starting from learning rate 0.010000:

# %%
"""
Assignment 2(c)
In the targeted classification task, we use cross entropy loss with L2 
regularization as the learning object.
You need to formulate the cross-entropy loss function in PyTorch.
You should also specify a PyTorch Optimizer to optimize this loss function.
We recommend you to use the SGD-momentum with an initial learning rate 0.01 
and momentum 0.9 as a start.
"""
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(net.parameters(), INITIAL_LR, MOMENTUM, weight_decay=REG)

# %%
"""
Assignment 3(a)
Start the training process over the whole CIFAR-10 training dataset. 
For sanity check, you are required to report the initial loss value at 
the beginning of the training process and briefly justify this value. 
Run the training process for \textbf{a maximum of 30} epochs and you 
should be able to reach around \textbf{65\%} accuracy on the validation 
dataset.
"""
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
global_step = 0
best_val_acc = 0

for i in range(start_epoch, EPOCHS):
    print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    # Train the training dataset for 1 epoch.
    print(len(trainloader))
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        # Now backward loss
        loss.backward()
        # Apply gradient
        optimizer.step()
        # Calculate predicted labels
        _, predicted = torch.max(outputs.data, 1)
        # Calculate accuracy
        total_examples += targets.size(0)
        correct_examples += predicted.eq(targets.data).sum().item()
        train_loss += loss.data.item()

        global_step += 1
        if global_step % 100 == 0:
            avg_loss = train_loss / (batch_idx + 1)
        pass
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f %%" %(avg_loss, avg_acc*100))
    print(datetime.datetime.now())
    # Validate on the validation dataset
    print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            # Calculate predicted labels
            _, predicted = torch.max(outputs.data, 1)
            # Calculate accuracy
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets.data).sum().item()
            val_loss += loss.data.item()

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f %%" %(avg_loss, avg_acc*100))

        
    """
    Assignment 4(b)
    Learning rate is an important hyperparameter to tune. Specify a 
    learning rate decay policy and apply it in your training process. 
    Briefly describe its impact on the learning curveduring your 
    training process.    
    Reference learning rate schedule: 
    decay 0.98 for every 2 epochs. You may tune this parameter but 
    minimal gain will be achieved.
    Assignment 4(c)
    As we can see from above, hyperparameter optimization is critical 
    to obtain a good performance of DNN models. Try to fine-tune the 
    model to over 70% accuracy. You may also increase the number of 
    epochs to up to 100 during the process. Briefly describe what you 
    have tried to improve the performance of the LeNet-5 model.
    """
    DECAY_EPOCHS = 2
    DECAY = 0.98#0.98
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = INITIAL_LR*(DECAY**i)
        for param_group in optimizer.param_groups:
            # Assign the learning rate parameter
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %(current_learning_rate*(DECAY**i)))
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
# Out:
# 2019-09-30 22:33:25.432103
# Epoch 0:
# 704
# Training loss: 1.6342, Training accuracy: 40.1867 %
# 2019-09-30 22:33:38.481705
# Validation...
# Validation loss: 1.3566, Validation accuracy: 51.2200 %
# Saving ...
# 2019-09-30 22:33:43.969890
# Epoch 1:
# 704
# Training loss: 1.3772, Training accuracy: 50.3778 %
# 2019-09-30 22:33:56.600524
# Validation...
# Validation loss: 1.2127, Validation accuracy: 57.3000 %
# Saving ...
# 2019-09-30 22:34:02.088292
# Epoch 2:
# 704
# Training loss: 1.2432, Training accuracy: 55.6289 %
# 2019-09-30 22:34:14.749810
# Validation...
# Validation loss: 1.1157, Validation accuracy: 61.1400 %
# Current learning rate has decayed to 0.009224
# Saving ...
# 2019-09-30 22:34:20.236808
# Epoch 3:
# 704
# Training loss: 1.1513, Training accuracy: 59.1844 %
# 2019-09-30 22:34:32.861808
# Validation...
# Validation loss: 0.9641, Validation accuracy: 64.9000 %
# Saving ...
# 2019-09-30 22:34:38.396809
# Epoch 4:
# 704
# Training loss: 1.0959, Training accuracy: 61.1756 %
# 2019-09-30 22:34:51.090871
# Validation...
# Validation loss: 0.9203, Validation accuracy: 67.1800 %
# Current learning rate has decayed to 0.008508
# Saving ...
# 2019-09-30 22:34:56.568873
# Epoch 5:
# 704
# Training loss: 1.0528, Training accuracy: 62.8289 %
# 2019-09-30 22:35:09.124871
# Validation...
# Validation loss: 0.8989, Validation accuracy: 68.0800 %
# Saving ...
# 2019-09-30 22:35:14.524870
# Epoch 6:
# 704
# Training loss: 1.0093, Training accuracy: 64.4422 %
# 2019-09-30 22:35:27.152870
# Validation...
# Validation loss: 0.8350, Validation accuracy: 69.8000 %
# Current learning rate has decayed to 0.007847
# Saving ...
# 2019-09-30 22:35:32.596870
# Epoch 7:
# 704
# Training loss: 0.9721, Training accuracy: 65.4489 %
# 2019-09-30 22:35:45.360944
# Validation...
# Validation loss: 0.8356, Validation accuracy: 70.3800 %
# Saving ...
# 2019-09-30 22:35:50.816942
# Epoch 8:
# 704
# Training loss: 0.9420, Training accuracy: 66.9000 %
# 2019-09-30 22:36:03.565238
# Validation...
# Validation loss: 0.8519, Validation accuracy: 70.5000 %
# Current learning rate has decayed to 0.007238
# Saving ...
# 2019-09-30 22:36:09.115581
# Epoch 9:
# 704
# Training loss: 0.9285, Training accuracy: 67.1822 %
# 2019-09-30 22:36:21.966159
# Validation...
# Validation loss: 0.8873, Validation accuracy: 68.8600 %
# 2019-09-30 22:36:27.452159
# Epoch 10:
# 704
# Training loss: 0.9051, Training accuracy: 68.2178 %
# 2019-09-30 22:36:40.062189
# Validation...
# Validation loss: 0.7898, Validation accuracy: 72.9200 %
# Current learning rate has decayed to 0.006676
# Saving ...
# 2019-09-30 22:36:45.593189
# Epoch 11:
# 704
# Training loss: 0.8885, Training accuracy: 68.8822 %
# 2019-09-30 22:36:58.161191
# Validation...
# Validation loss: 0.7555, Validation accuracy: 73.9000 %
# Saving ...
# 2019-09-30 22:37:03.661188
# Epoch 12:
# 704
# Training loss: 0.8701, Training accuracy: 69.4378 %
# 2019-09-30 22:37:16.269740
# Validation...
# Validation loss: 0.7653, Validation accuracy: 73.6400 %
# Current learning rate has decayed to 0.006158
# 2019-09-30 22:37:21.654937
# Epoch 13:
# 704
# Training loss: 0.8479, Training accuracy: 69.9533 %
# 2019-09-30 22:37:34.276937
# Validation...
# Validation loss: 0.7629, Validation accuracy: 73.2200 %
# 2019-09-30 22:37:39.601935
# Epoch 14:
# 704
# Training loss: 0.8480, Training accuracy: 70.1378 %
# 2019-09-30 22:37:52.216935
# Validation...
# Validation loss: 0.7626, Validation accuracy: 74.0000 %
# Current learning rate has decayed to 0.005680
# Saving ...
# 2019-09-30 22:37:57.677936
# Epoch 15:
# 704
# Training loss: 0.8293, Training accuracy: 70.8733 %
# 2019-09-30 22:38:10.336012
# Validation...
# Validation loss: 0.7304, Validation accuracy: 74.5400 %
# Saving ...
# 2019-09-30 22:38:15.736010
# Epoch 16:
# 704
# Training loss: 0.8154, Training accuracy: 71.3667 %
# 2019-09-30 22:38:28.407040
# Validation...
# Validation loss: 0.7264, Validation accuracy: 75.6000 %
# Current learning rate has decayed to 0.005239
# Saving ...
# 2019-09-30 22:38:33.864071
# Epoch 17:
# 704
# Training loss: 0.7974, Training accuracy: 72.0267 %
# 2019-09-30 22:38:46.476127
# Validation...
# Validation loss: 0.7243, Validation accuracy: 75.1400 %
# 2019-09-30 22:38:51.933126
# Epoch 18:
# 704
# Training loss: 0.8007, Training accuracy: 71.8667 %
# 2019-09-30 22:39:04.588638
# Validation...
# Validation loss: 0.7291, Validation accuracy: 75.0400 %
# Current learning rate has decayed to 0.004832
# 2019-09-30 22:39:09.997639
# Epoch 19:
# 704
# Training loss: 0.7799, Training accuracy: 72.8022 %
# 2019-09-30 22:39:22.528639
# Validation...
# Validation loss: 0.7244, Validation accuracy: 74.7600 %
# 2019-09-30 22:39:27.831638
# Epoch 20:
# 704
# Training loss: 0.7714, Training accuracy: 72.8889 %
# 2019-09-30 22:39:40.484697
# Validation...
# Validation loss: 0.7052, Validation accuracy: 75.7200 %
# Current learning rate has decayed to 0.004457
# Saving ...
# 2019-09-30 22:39:45.962695
# Epoch 21:
# 704
# Training loss: 0.7624, Training accuracy: 73.3089 %
# 2019-09-30 22:39:58.584696
# Validation...
# Validation loss: 0.7233, Validation accuracy: 75.2800 %
# 2019-09-30 22:40:03.884696
# Epoch 22:
# 704
# Training loss: 0.7557, Training accuracy: 73.7778 %
# 2019-09-30 22:40:16.473211
# Validation...
# Validation loss: 0.6857, Validation accuracy: 76.2000 %
# Current learning rate has decayed to 0.004111
# Saving ...
# 2019-09-30 22:40:21.914209
# Epoch 23:
# 704
# Training loss: 0.7482, Training accuracy: 73.8044 %
# 2019-09-30 22:40:34.589211
# Validation...
# Validation loss: 0.7037, Validation accuracy: 75.6600 %
# 2019-09-30 22:40:40.004265
# Epoch 24:
# 704
# Training loss: 0.7467, Training accuracy: 74.3089 %
# 2019-09-30 22:40:52.700308
# Validation...
# Validation loss: 0.7500, Validation accuracy: 74.4600 %
# Current learning rate has decayed to 0.003792
# 2019-09-30 22:40:58.063312
# Epoch 25:
# 704
# Training loss: 0.7316, Training accuracy: 74.7689 %
# 2019-09-30 22:41:10.757878
# Validation...
# Validation loss: 0.6985, Validation accuracy: 76.3000 %
# Saving ...
# 2019-09-30 22:41:16.397878
# Epoch 26:
# 704
# Training loss: 0.7264, Training accuracy: 74.8044 %
# 2019-09-30 22:41:28.971878
# Validation...
# Validation loss: 0.6951, Validation accuracy: 76.4800 %
# Current learning rate has decayed to 0.003497
# Saving ...
# 2019-09-30 22:41:34.524878
# Epoch 27:
# 704
# Training loss: 0.7183, Training accuracy: 75.0733 %
# 2019-09-30 22:41:47.101961
# Validation...
# Validation loss: 0.6920, Validation accuracy: 76.2000 %
# 2019-09-30 22:41:52.434961
# Epoch 28:
# 704
# Training loss: 0.7101, Training accuracy: 75.5533 %
# 2019-09-30 22:42:05.002960
# Validation...
# Validation loss: 0.6981, Validation accuracy: 76.0400 %
# Current learning rate has decayed to 0.003226
# 2019-09-30 22:42:10.339021
# Epoch 29:
# 704
# Training loss: 0.7062, Training accuracy: 75.7200 %
# 2019-09-30 22:42:23.116076
# Validation...
# Validation loss: 0.6911, Validation accuracy: 76.5600 %
# Saving ...
# 2019-09-30 22:42:28.554075
# Epoch 30:
# 704
# Training loss: 0.7030, Training accuracy: 75.8200 %
# 2019-09-30 22:42:41.275075
# Validation...
# Validation loss: 0.6966, Validation accuracy: 76.3000 %
# Current learning rate has decayed to 0.002976
# 2019-09-30 22:42:46.707076
# Epoch 31:
# 704
# Training loss: 0.6927, Training accuracy: 76.1778 %
# 2019-09-30 22:42:59.432103
# Validation...
# Validation loss: 0.7081, Validation accuracy: 76.3200 %
# 2019-09-30 22:43:04.735102
# Epoch 32:
# 704
# Training loss: 0.6938, Training accuracy: 76.3022 %
# 2019-09-30 22:43:17.447096
# Validation...
# Validation loss: 0.6910, Validation accuracy: 76.9400 %
# Current learning rate has decayed to 0.002745
# Saving ...
# 2019-09-30 22:43:22.968095
# Epoch 33:
# 704
# Training loss: 0.6827, Training accuracy: 76.5400 %
# 2019-09-30 22:43:35.725374
# Validation...
# Validation loss: 0.6896, Validation accuracy: 76.9800 %
# Saving ...
# 2019-09-30 22:43:41.235374
# Epoch 34:
# 704
# Training loss: 0.6721, Training accuracy: 76.8800 %
# 2019-09-30 22:43:53.968376
# Validation...
# Validation loss: 0.6756, Validation accuracy: 77.0400 %
# Current learning rate has decayed to 0.002531
# Saving ...
# 2019-09-30 22:43:59.554102
# Epoch 35:
# 704
# Training loss: 0.6694, Training accuracy: 77.0311 %
# 2019-09-30 22:44:12.474652
# Validation...
# Validation loss: 0.6732, Validation accuracy: 76.7400 %
# 2019-09-30 22:44:17.994189
# Epoch 36:
# 704
# Training loss: 0.6642, Training accuracy: 77.2000 %
# 2019-09-30 22:44:30.635189
# Validation...
# Validation loss: 0.7399, Validation accuracy: 75.3800 %
# Current learning rate has decayed to 0.002335
# 2019-09-30 22:44:35.982189
# Epoch 37:
# 704
# Training loss: 0.6569, Training accuracy: 77.7178 %
# 2019-09-30 22:44:48.797710
# Validation...
# Validation loss: 0.6922, Validation accuracy: 76.4400 %
# 2019-09-30 22:44:54.410315
# Epoch 38:
# 704
# Training loss: 0.6563, Training accuracy: 77.3222 %
# 2019-09-30 22:45:07.579601
# Validation...
# Validation loss: 0.6777, Validation accuracy: 77.3600 %
# Current learning rate has decayed to 0.002154
# Saving ...
# 2019-09-30 22:45:13.250050
# Epoch 39:
# 704
# Training loss: 0.6445, Training accuracy: 77.9733 %
# 2019-09-30 22:45:26.420686
# Validation...
# Validation loss: 0.7055, Validation accuracy: 75.7600 %
# 2019-09-30 22:45:32.158527
# Epoch 40:
# 704
# Training loss: 0.6483, Training accuracy: 77.7067 %
# 2019-09-30 22:45:45.253686
# Validation...
# Validation loss: 0.6765, Validation accuracy: 76.7000 %
# Current learning rate has decayed to 0.001986
# 2019-09-30 22:45:50.797286
# Epoch 41:
# 704
# Training loss: 0.6414, Training accuracy: 78.3444 %
# 2019-09-30 22:46:03.803112
# Validation...
# Validation loss: 0.6681, Validation accuracy: 78.1800 %
# Saving ...
# 2019-09-30 22:46:09.258313
# Epoch 42:
# 704
# Training loss: 0.6357, Training accuracy: 78.4444 %
# 2019-09-30 22:46:21.889035
# Validation...
# Validation loss: 0.6736, Validation accuracy: 77.1200 %
# Current learning rate has decayed to 0.001832
# 2019-09-30 22:46:27.318119
# Epoch 43:
# 704
# Training loss: 0.6378, Training accuracy: 78.2667 %
# 2019-09-30 22:46:39.992681
# Validation...
# Validation loss: 0.6821, Validation accuracy: 76.8200 %
# 2019-09-30 22:46:45.334681
# Epoch 44:
# 704
# Training loss: 0.6229, Training accuracy: 78.9022 %
# 2019-09-30 22:46:58.239331
# Validation...
# Validation loss: 0.6986, Validation accuracy: 76.6600 %
# Current learning rate has decayed to 0.001690
# 2019-09-30 22:47:03.645861
# Epoch 45:
# 704
# Training loss: 0.6270, Training accuracy: 78.6267 %
# 2019-09-30 22:47:16.379057
# Validation...
# Validation loss: 0.6789, Validation accuracy: 76.9400 %
# 2019-09-30 22:47:21.976575
# Epoch 46:
# 704
# Training loss: 0.6220, Training accuracy: 78.8311 %
# 2019-09-30 22:47:34.726715
# Validation...
# Validation loss: 0.7035, Validation accuracy: 76.5400 %
# Current learning rate has decayed to 0.001559
# 2019-09-30 22:47:40.164985
# Epoch 47:
# 704
# Training loss: 0.6175, Training accuracy: 79.4067 %
# 2019-09-30 22:47:52.935062
# Validation...
# Validation loss: 0.6546, Validation accuracy: 77.5200 %
# 2019-09-30 22:47:58.331238
# Epoch 48:
# 704
# Training loss: 0.6207, Training accuracy: 79.2600 %
# 2019-09-30 22:48:11.090364
# Validation...
# Validation loss: 0.6815, Validation accuracy: 77.0400 %
# Current learning rate has decayed to 0.001438
# 2019-09-30 22:48:16.478199
# Epoch 49:
# 704
# Training loss: 0.6122, Training accuracy: 79.1489 %
# 2019-09-30 22:48:29.160533
# Validation...
# Validation loss: 0.6786, Validation accuracy: 77.0600 %
# 2019-09-30 22:48:34.489683
# Epoch 50:
# 704
# Training loss: 0.6079, Training accuracy: 79.6711 %
# 2019-09-30 22:48:47.240683
# Validation...
# Validation loss: 0.6779, Validation accuracy: 77.1200 %
# Current learning rate has decayed to 0.001326
# 2019-09-30 22:48:52.615968
# Epoch 51:
# 704
# Training loss: 0.5994, Training accuracy: 79.7244 %
# 2019-09-30 22:49:05.721407
# Validation...
# Validation loss: 0.6833, Validation accuracy: 77.5400 %
# 2019-09-30 22:49:11.130407
# Epoch 52:
# 704
# Training loss: 0.5970, Training accuracy: 79.9622 %
# 2019-09-30 22:49:23.956609
# Validation...
# Validation loss: 0.6581, Validation accuracy: 78.2200 %
# Current learning rate has decayed to 0.001223
# Saving ...
# 2019-09-30 22:49:29.454675
# Epoch 53:
# 704
# Training loss: 0.5994, Training accuracy: 79.8133 %
# 2019-09-30 22:49:42.207493
# Validation...
# Validation loss: 0.6673, Validation accuracy: 77.9000 %
# 2019-09-30 22:49:47.703165
# Epoch 54:
# 704
# Training loss: 0.5998, Training accuracy: 80.0267 %
# 2019-09-30 22:50:00.745418
# Validation...
# Validation loss: 0.6637, Validation accuracy: 77.8600 %
# Current learning rate has decayed to 0.001128
# 2019-09-30 22:50:06.153523
# Epoch 55:
# 704
# Training loss: 0.5922, Training accuracy: 80.2822 %
# 2019-09-30 22:50:18.744627
# Validation...
# Validation loss: 0.6795, Validation accuracy: 77.2400 %
# 2019-09-30 22:50:24.229148
# Epoch 56:
# 704
# Training loss: 0.5876, Training accuracy: 80.3267 %
# 2019-09-30 22:50:36.877163
# Validation...
# Validation loss: 0.6857, Validation accuracy: 77.3000 %
# Current learning rate has decayed to 0.001041
# 2019-09-30 22:50:42.366783
# Epoch 57:
# 704
# Training loss: 0.5932, Training accuracy: 80.5267 %
# 2019-09-30 22:50:55.420702
# Validation...
# Validation loss: 0.6735, Validation accuracy: 77.9000 %
# 2019-09-30 22:51:00.879820
# Epoch 58:
# 704
# Training loss: 0.5794, Training accuracy: 80.4400 %
# 2019-09-30 22:51:13.915376
# Validation...
# Validation loss: 0.6722, Validation accuracy: 77.4800 %
# Current learning rate has decayed to 0.000960
# 2019-09-30 22:51:19.263375
# Epoch 59:
# 704
# Training loss: 0.5803, Training accuracy: 80.4444 %
# 2019-09-30 22:51:32.143373
# Validation...
# Validation loss: 0.6633, Validation accuracy: 78.1400 %
# 2019-09-30 22:51:37.542372
# Epoch 60:
# 704
# Training loss: 0.5825, Training accuracy: 80.4089 %
# 2019-09-30 22:51:50.556938
# Validation...
# Validation loss: 0.6666, Validation accuracy: 77.8200 %
# Current learning rate has decayed to 0.000885
# 2019-09-30 22:51:56.037913
# Epoch 61:
# 704
# Training loss: 0.5687, Training accuracy: 80.8867 %
# 2019-09-30 22:52:08.957226
# Validation...
# Validation loss: 0.6622, Validation accuracy: 78.4000 %
# Saving ...
# 2019-09-30 22:52:14.699822
# Epoch 62:
# 704
# Training loss: 0.5741, Training accuracy: 80.7133 %
# 2019-09-30 22:52:27.441892
# Validation...
# Validation loss: 0.6647, Validation accuracy: 78.2200 %
# Current learning rate has decayed to 0.000817
# 2019-09-30 22:52:32.864975
# Epoch 63:
# 704
# Training loss: 0.5734, Training accuracy: 81.0822 %
# 2019-09-30 22:52:45.427259
# Validation...
# Validation loss: 0.6751, Validation accuracy: 77.7800 %
# 2019-09-30 22:52:50.781283
# Epoch 64:
# 704
# Training loss: 0.5714, Training accuracy: 80.9867 %
# 2019-09-30 22:53:03.397283
# Validation...
# Validation loss: 0.6663, Validation accuracy: 77.9400 %
# Current learning rate has decayed to 0.000753
# 2019-09-30 22:53:08.730283
# Epoch 65:
# 704
# Training loss: 0.5729, Training accuracy: 80.9511 %
# 2019-09-30 22:53:21.180473
# Validation...
# Validation loss: 0.6573, Validation accuracy: 77.8400 %
# 2019-09-30 22:53:26.561471
# Epoch 66:
# 704
# Training loss: 0.5607, Training accuracy: 81.4000 %
# 2019-09-30 22:53:39.044474
# Validation...
# Validation loss: 0.6541, Validation accuracy: 78.8600 %
# Current learning rate has decayed to 0.000695
# Saving ...
# 2019-09-30 22:53:44.496505
# Epoch 67:
# 704
# Training loss: 0.5754, Training accuracy: 80.8067 %
# 2019-09-30 22:53:57.031505
# Validation...
# Validation loss: 0.6570, Validation accuracy: 78.5400 %
# 2019-09-30 22:54:02.346507
# Epoch 68:
# 704
# Training loss: 0.5683, Training accuracy: 81.0667 %
# 2019-09-30 22:54:14.778504
# Validation...
# Validation loss: 0.6529, Validation accuracy: 78.4400 %
# Current learning rate has decayed to 0.000641
# 2019-09-30 22:54:20.226504
# Epoch 69:
# 704
# Training loss: 0.5607, Training accuracy: 81.4844 %
# 2019-09-30 22:54:32.773505
# Validation...
# Validation loss: 0.6595, Validation accuracy: 78.1200 %
# 2019-09-30 22:54:38.172504
# Epoch 70:
# 704
# Training loss: 0.5634, Training accuracy: 81.2556 %
# 2019-09-30 22:54:50.640506
# Validation...
# Validation loss: 0.6654, Validation accuracy: 77.7800 %
# Current learning rate has decayed to 0.000591
# 2019-09-30 22:54:55.934505
# Epoch 71:
# 704
# Training loss: 0.5541, Training accuracy: 81.6289 %
# 2019-09-30 22:55:08.401504
# Validation...
# Validation loss: 0.6526, Validation accuracy: 78.5000 %
# 2019-09-30 22:55:13.680505
# Epoch 72:
# 704
# Training loss: 0.5476, Training accuracy: 81.8333 %
# 2019-09-30 22:55:26.133536
# Validation...
# Validation loss: 0.6604, Validation accuracy: 78.0800 %
# Current learning rate has decayed to 0.000545
# 2019-09-30 22:55:31.473818
# Epoch 73:
# 704
# Training loss: 0.5564, Training accuracy: 81.5356 %
# 2019-09-30 22:55:43.991816
# Validation...
# Validation loss: 0.6625, Validation accuracy: 78.2200 %
# 2019-09-30 22:55:49.286816
# Epoch 74:
# 704
# Training loss: 0.5562, Training accuracy: 81.7133 %
# 2019-09-30 22:56:01.883815
# Validation...
# Validation loss: 0.6585, Validation accuracy: 78.2800 %
# Current learning rate has decayed to 0.000503
# 2019-09-30 22:56:07.202817
# Epoch 75:
# 704
# Training loss: 0.5502, Training accuracy: 81.6711 %
# 2019-09-30 22:56:19.663816
# Validation...
# Validation loss: 0.6636, Validation accuracy: 78.3000 %
# 2019-09-30 22:56:24.968815
# Epoch 76:
# 704
# Training loss: 0.5458, Training accuracy: 81.9378 %
# 2019-09-30 22:56:37.461817
# Validation...
# Validation loss: 0.6674, Validation accuracy: 77.7400 %
# Current learning rate has decayed to 0.000464
# 2019-09-30 22:56:42.828817
# Epoch 77:
# 704
# Training loss: 0.5452, Training accuracy: 82.0133 %
# 2019-09-30 22:56:55.268816
# Validation...
# Validation loss: 0.6649, Validation accuracy: 78.3800 %
# 2019-09-30 22:57:00.757815
# Epoch 78:
# 704
# Training loss: 0.5407, Training accuracy: 82.2422 %
# 2019-09-30 22:57:13.251873
# Validation...
# Validation loss: 0.6490, Validation accuracy: 78.1800 %
# Current learning rate has decayed to 0.000428
# 2019-09-30 22:57:18.660872
# Epoch 79:
# 704
# Training loss: 0.5407, Training accuracy: 82.3133 %
# 2019-09-30 22:57:31.176871
# Validation...
# Validation loss: 0.6480, Validation accuracy: 79.0800 %
# Saving ...
# 2019-09-30 22:57:36.611871
# Epoch 80:
# 704
# Training loss: 0.5432, Training accuracy: 82.2000 %
# 2019-09-30 22:57:49.100873
# Validation...
# Validation loss: 0.6545, Validation accuracy: 78.5200 %
# Current learning rate has decayed to 0.000395
# 2019-09-30 22:57:54.386871
# Epoch 81:
# 704
# Training loss: 0.5364, Training accuracy: 82.1689 %
# 2019-09-30 22:58:06.884872
# Validation...
# Validation loss: 0.6581, Validation accuracy: 78.5600 %
# 2019-09-30 22:58:12.180872
# Epoch 82:
# 704
# Training loss: 0.5347, Training accuracy: 82.3044 %
# 2019-09-30 22:58:24.613873
# Validation...
# Validation loss: 0.6553, Validation accuracy: 78.6200 %
# Current learning rate has decayed to 0.000364
# 2019-09-30 22:58:29.941873
# Epoch 83:
# 704
# Training loss: 0.5242, Training accuracy: 82.7378 %
# 2019-09-30 22:58:42.524872
# Validation...
# Validation loss: 0.6593, Validation accuracy: 78.6000 %
# 2019-09-30 22:58:47.856872
# Epoch 84:
# 704
# Training loss: 0.5332, Training accuracy: 82.5333 %
# 2019-09-30 22:59:00.334036
# Validation...
# Validation loss: 0.6539, Validation accuracy: 78.6600 %
# Current learning rate has decayed to 0.000336
# 2019-09-30 22:59:05.645036
# Epoch 85:
# 704
# Training loss: 0.5280, Training accuracy: 82.8000 %
# 2019-09-30 22:59:18.123063
# Validation...
# Validation loss: 0.6551, Validation accuracy: 78.8200 %
# 2019-09-30 22:59:23.501176
# Epoch 86:
# 704
# Training loss: 0.5287, Training accuracy: 82.5111 %
# 2019-09-30 22:59:36.037178
# Validation...
# Validation loss: 0.6539, Validation accuracy: 78.7800 %
# Current learning rate has decayed to 0.000310
# 2019-09-30 22:59:41.375424
# Epoch 87:
# 704
# Training loss: 0.5324, Training accuracy: 82.6622 %
# 2019-09-30 22:59:53.843424
# Validation...
# Validation loss: 0.6573, Validation accuracy: 79.0400 %
# 2019-09-30 22:59:59.182422
# Epoch 88:
# 704
# Training loss: 0.5306, Training accuracy: 82.5333 %
# 2019-09-30 23:00:11.873273
# Validation...
# Validation loss: 0.6622, Validation accuracy: 78.4000 %
# Current learning rate has decayed to 0.000286
# 2019-09-30 23:00:17.163788
# Epoch 89:
# 704
# Training loss: 0.5288, Training accuracy: 82.6111 %
# 2019-09-30 23:00:29.867788
# Validation...
# Validation loss: 0.6521, Validation accuracy: 78.7200 %
# 2019-09-30 23:00:35.177787
# Epoch 90:
# 704
# Training loss: 0.5204, Training accuracy: 82.7978 %
# 2019-09-30 23:00:47.669813
# Validation...
# Validation loss: 0.6570, Validation accuracy: 79.0000 %
# Current learning rate has decayed to 0.000263
# 2019-09-30 23:00:52.980812
# Epoch 91:
# 704
# Training loss: 0.5250, Training accuracy: 82.8867 %
# 2019-09-30 23:01:05.600814
# Validation...
# Validation loss: 0.6536, Validation accuracy: 79.0000 %
# 2019-09-30 23:01:10.925812
# Epoch 92:
# 704
# Training loss: 0.5202, Training accuracy: 82.8178 %
# 2019-09-30 23:01:23.480839
# Validation...
# Validation loss: 0.6540, Validation accuracy: 78.3200 %
# Current learning rate has decayed to 0.000243
# 2019-09-30 23:01:28.835841
# Epoch 93:
# 704
# Training loss: 0.5151, Training accuracy: 83.0378 %
# 2019-09-30 23:01:41.482353
# Validation...
# Validation loss: 0.6586, Validation accuracy: 78.7200 %
# 2019-09-30 23:01:46.905356
# Epoch 94:
# 704
# Training loss: 0.5123, Training accuracy: 83.1733 %
# 2019-09-30 23:01:59.295353
# Validation...
# Validation loss: 0.6625, Validation accuracy: 78.5200 %
# Current learning rate has decayed to 0.000224
# 2019-09-30 23:02:04.640354
# Epoch 95:
# 704
# Training loss: 0.5238, Training accuracy: 82.9667 %
# 2019-09-30 23:02:17.059869
# Validation...
# Validation loss: 0.6579, Validation accuracy: 79.0200 %
# 2019-09-30 23:02:22.443868
# Epoch 96:
# 704
# Training loss: 0.5080, Training accuracy: 83.3956 %
# 2019-09-30 23:02:35.001867
# Validation...
# Validation loss: 0.6603, Validation accuracy: 78.9000 %
# Current learning rate has decayed to 0.000207
# 2019-09-30 23:02:40.323871
# Epoch 97:
# 704
# Training loss: 0.5184, Training accuracy: 82.9800 %
# 2019-09-30 23:02:52.770219
# Validation...
# Validation loss: 0.6571, Validation accuracy: 78.7800 %
# 2019-09-30 23:02:58.129219
# Epoch 98:
# 704
# Training loss: 0.5167, Training accuracy: 83.0622 %
# 2019-09-30 23:03:10.642220
# Validation...
# Validation loss: 0.6576, Validation accuracy: 78.7000 %
# Current learning rate has decayed to 0.000191
# 2019-09-30 23:03:15.922220
# Epoch 99:
# 704
# Training loss: 0.5149, Training accuracy: 83.1889 %
# 2019-09-30 23:03:28.463245
# Validation...
# Validation loss: 0.6581, Validation accuracy: 78.5200 %
# Optimization finished.
