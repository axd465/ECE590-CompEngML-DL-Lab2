# %% [markdown]
# # ECE 590 - Lab2 - LeNet5 Cifar 10 - Anthony DiSpirito

# %% [markdown]
# ## My Info
# * **Name: Anthony DiSpirito**
# * **NetID: ad424**
# * **Class: ECE 590 - Comp Eng ML and DL**
# * **Title: Lab2 - LeNet5 Cifar10**
# * **Date: 10/2/19**

# %% [markdown]
# ## Build LeNet5 Model

# %% [markdown]
# ### Import Statements

# %%
import argparse
import os, sys
import math
import random
import time
import datetime

# Import pytorch dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import torch.backends.cudnn as cudnn
from tqdm import tqdm_notebook as tqdm

# You cannot change this line.
from tools.dataloader import CIFAR10

# %% [markdown]
# ### My Model Class

# %%
""" 
Assignment 2(a)
Build the LeNet-5 model by following table 1 or figure 1.

You can also insert batch normalization and leave the LeNet-5 
with batch normalization here for assignment 3(c).
"""
# Create the neural network module: LeNet-5
class MyModel(nn.Module):
    def __init__(self):
        '''
        FUNCTIONS USED IN THIS SECTION:
        -----------------------------------------
        Conv2d Function takes form:
        
        torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride=1,
                        padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros')
        -----------------------------------------
        BatchNorm2d Function takes the form:
        
        torch.nn.BatchNorm2d(num_features, eps=1e-05, momentum=0.1,
                             affine=True, track_running_stats=True)
        -----------------------------------------
        Linear Function:
        torch.nn.Linear(in_features, out_features, bias=True)
        '''
        super(MyModel, self).__init__()
        # Convolutional Layers
        self.conv1 = nn.Conv2d(3, 6, 5, padding=0, dilation=1,
                               groups=1, bias=True, padding_mode='zeros')
        self.bn_conv1 = nn.BatchNorm2d(6, eps=1e-05,momentum=0.1, 
                                       affine=True, track_running_stats=True)
        self.conv2 = nn.Conv2d(6, 16, 5, padding=0, dilation=1,
                               groups=1, bias=True, padding_mode='zeros')
        self.bn_conv2 = nn.BatchNorm2d(16, eps=1e-05, momentum=0.1,
                                       affine=True, track_running_stats=True)
        #______________________________
        # My Addition
        self.conv3 = nn.Conv2d(16, 32, 3, padding=0, dilation=1,
                               groups=1, bias=True, padding_mode='zeros')
        self.bn_conv3 = nn.BatchNorm2d(32, eps=1e-05, momentum=0.1,
                                       affine=True, track_running_stats=True)
        self.conv4 = nn.Conv2d(32, 64, 1, padding=0, dilation=1,
                               groups=1, bias=True, padding_mode='zeros')
        self.bn_conv4 = nn.BatchNorm2d(64, eps=1e-05, momentum=0.1,
                                       affine=True, track_running_stats=True)
        self.fc1 = nn.Linear(64*(5**2), 128, bias = True)
        torch.nn.init.xavier_normal(self.fc1.weight)
        self.fc2 = nn.Linear(128, 10, bias = True)
        torch.nn.init.xavier_normal(self.fc2.weight)
        #______________________________
        # Fully Connected Layers
        #self.fc1 = nn.Linear(16*(5**2), 120, bias = True)
        #self.fc2 = nn.Linear(120, 84, bias = True)     
        #self.fc3 = nn.Linear(84, 10, bias = True)
        return
    
    def forward(self, x):
        # First Convolutional Layer (ReLu activation)
        out = F.elu(self.bn_conv1(self.conv1(x)))
        # First Pooling Layer (2x2 strides and pooling size)
        
        # Second Convolutional Layer (ReLu activation)
        out = F.elu(self.bn_conv2(self.conv2(out)))
        # Second Pooling Layer (2x2 strides and pooling size)
        out = F.max_pool2d(out, 2)
        #______________________________
        # My Addition
        out = F.elu(self.bn_conv3(self.conv3(out)))
        out = F.elu(self.bn_conv4(self.conv4(out)))
        out = F.max_pool2d(out, 2)
        #______________________________
        # Reshapes "out" so we can input into Fully Connected Layer
        out = out.view(out.size(0), -1)
        # First Fully Connected Layer (ReLu activation)
        out = F.elu(self.fc1(out))
        # Second Fully Connected Layer (ReLu activation)
        out = self.fc2(out) #out = F.relu(self.fc2(out))
        # Third Fully Connected Layer (Softmax activation)
        #out = self.fc3(out)#F.softmax(self.fc3(out), dim=0)
        return out

# %% [markdown]
# ### Setting Hyperparameters

# %%
"""
Hyperparameter optimization in assignment 4(a), 4(b) can be 
conducted here.
Be sure to leave only your best hyperparameter combination
here and comment the original hyperparameter settings.
"""

# Setting some hyperparameters
TRAIN_BATCH_SIZE = 128#64#128
VAL_BATCH_SIZE = 100#50#100
INITIAL_LR = 0.01
MOMENTUM = 0.9
REG = 1e-4
EPOCHS = 200#100 #30
DATAROOT = "./data"
CHECKPOINT_PATH = "./saved_model"

# %%
"""
Assignment 2(b)
Write functions to load dataset and preprocess the incoming data. 
We recommend that the preprocess scheme \textbf{must} include 
normalize, standardization, batch shuffling to make sure the training 
process goes smoothly. 
The preprocess scheme may also contain some data augmentation methods 
(e.g., random crop, random flip, etc.). 

Reference value for mean/std:

mean(RGB-format): (0.4914, 0.4822, 0.4465)
std(RGB-format): (0.2023, 0.1994, 0.2010)


NOTE: Considering this process has strong corrlelation with assignment 3(b), 
please leave the data preprocessing method which can achieve the highest 
validation accuracy here. You can include your original data augmentation
method as comments and denotes the accuracy difference between these two 
methods.
"""
# Specify preprocessing function.
# Reference mean/std value
mean_RGB = (0.4914, 0.4822, 0.4465)
std_RGB = (0.2023, 0.1994, 0.2010)
input_img_size = (32,32)
percent_crop = 0.80 # 80 percent left after crop
data_augment_list = [#transforms.RandomResizedCrop(size = input_img_size, scale=(percent_crop, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=2),
                     transforms.RandomVerticalFlip(p = 0.10),
                     transforms.RandomHorizontalFlip(p = 0.25),
                     transforms.RandomApply([transforms.RandomCrop(size = input_img_size, padding=4, pad_if_needed=False, fill=0, padding_mode='constant')], p = 0.15),
                     transforms.RandomApply([transforms.RandomAffine(degrees = 30, translate=(0.15,0.15), scale=None, shear=None, resample=False, fillcolor=0)], p = 0.15),
                     transforms.RandomApply([transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.05)], p = 0.10)]
transform_train = transforms.Compose([transforms.Resize(input_img_size),
                                      transforms.RandomOrder(data_augment_list),
                                      transforms.ToTensor(),
                                      transforms.RandomErasing(p=0.10, scale=(0.01, 0.15), ratio=(0.3, 3.3), value=0, inplace=False),
                                      transforms.Normalize(mean_RGB, std_RGB)])
transform_val = transforms.Compose([transforms.Resize(input_img_size),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean_RGB, std_RGB)])

# %%
# Call the dataset Loader
num_threads = 16
trainset = CIFAR10(root=DATAROOT, train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=num_threads//2)
valset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
valloader = torch.utils.data.DataLoader(valset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=num_threads//2)
# Out:
# Using downloaded and verified file: ./data\cifar10_trainval.tar.gz
# Extracting ./data\cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data\cifar10_trainval.tar.gz
# Extracting ./data\cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = MyModel()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %%
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = True
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# Training from scratch ...
# Starting from learning rate 0.010000:

# %%
"""
Assignment 2(c)
In the targeted classification task, we use cross entropy loss with L2 
regularization as the learning object.
You need to formulate the cross-entropy loss function in PyTorch.
You should also specify a PyTorch Optimizer to optimize this loss function.
We recommend you to use the SGD-momentum with an initial learning rate 0.01 
and momentum 0.9 as a start.
"""
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(net.parameters(), INITIAL_LR, MOMENTUM, weight_decay=REG, nesterov = True)

# %%
"""
Assignment 3(a)
Start the training process over the whole CIFAR-10 training dataset. 
For sanity check, you are required to report the initial loss value at 
the beginning of the training process and briefly justify this value. 
Run the training process for \textbf{a maximum of 30} epochs and you 
should be able to reach around \textbf{65\%} accuracy on the validation 
dataset.
"""
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
global_step = 0
best_val_acc = 0

for i in range(start_epoch, EPOCHS):
    print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    # Train the training dataset for 1 epoch.
    print(len(trainloader))
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        # Now backward loss
        loss.backward()
        # Apply gradient
        optimizer.step()
        # Calculate predicted labels
        _, predicted = torch.max(outputs.data, 1)
        # Calculate accuracy
        total_examples += targets.size(0)
        correct_examples += predicted.eq(targets.data).sum().item()
        train_loss += loss.data.item()

        global_step += 1
        if global_step % 100 == 0:
            avg_loss = train_loss / (batch_idx + 1)
        pass
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f %%" %(avg_loss, avg_acc*100))
    print(datetime.datetime.now())
    # Validate on the validation dataset
    print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            # Calculate predicted labels
            _, predicted = torch.max(outputs.data, 1)
            # Calculate accuracy
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets.data).sum().item()
            val_loss += loss.data.item()

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f %%" %(avg_loss, avg_acc*100))

        
    """
    Assignment 4(b)
    Learning rate is an important hyperparameter to tune. Specify a 
    learning rate decay policy and apply it in your training process. 
    Briefly describe its impact on the learning curveduring your 
    training process.    
    Reference learning rate schedule: 
    decay 0.98 for every 2 epochs. You may tune this parameter but 
    minimal gain will be achieved.
    Assignment 4(c)
    As we can see from above, hyperparameter optimization is critical 
    to obtain a good performance of DNN models. Try to fine-tune the 
    model to over 70% accuracy. You may also increase the number of 
    epochs to up to 100 during the process. Briefly describe what you 
    have tried to improve the performance of the LeNet-5 model.
    """
    DECAY_EPOCHS = 2
    DECAY = 0.98#0.98
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = INITIAL_LR*(DECAY**i)
        for param_group in optimizer.param_groups:
            # Assign the learning rate parameter
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %(current_learning_rate*(DECAY**i)))
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
# Out:
# 2019-10-01 01:59:25.238820
# Epoch 0:
# 352
# Training loss: 1.5717, Training accuracy: 43.7622 %
# 2019-10-01 01:59:35.045090
# Validation...
# Validation loss: 1.2729, Validation accuracy: 53.8800 %
# Saving ...
# 2019-10-01 01:59:40.316617
# Epoch 1:
# 352
# Training loss: 1.2832, Training accuracy: 54.1822 %
# 2019-10-01 01:59:50.090534
# Validation...
# Validation loss: 1.1058, Validation accuracy: 61.0200 %
# Saving ...
# 2019-10-01 01:59:55.326534
# Epoch 2:
# 352
# Training loss: 1.1792, Training accuracy: 58.1933 %
# 2019-10-01 02:00:05.195535
# Validation...
# Validation loss: 1.0556, Validation accuracy: 62.0600 %
# Current learning rate has decayed to 0.009224
# Saving ...
# 2019-10-01 02:00:10.479722
# Epoch 3:
# 352
# Training loss: 1.0886, Training accuracy: 61.4956 %
# 2019-10-01 02:00:20.297723
# Validation...
# Validation loss: 0.9261, Validation accuracy: 66.7200 %
# Saving ...
# 2019-10-01 02:00:25.557733
# Epoch 4:
# 352
# Training loss: 1.0363, Training accuracy: 63.5111 %
# 2019-10-01 02:00:35.296734
# Validation...
# Validation loss: 0.8653, Validation accuracy: 69.2800 %
# Current learning rate has decayed to 0.008508
# Saving ...
# 2019-10-01 02:00:40.554733
# Epoch 5:
# 352
# Training loss: 0.9875, Training accuracy: 65.0111 %
# 2019-10-01 02:00:50.292734
# Validation...
# Validation loss: 0.8726, Validation accuracy: 68.2800 %
# 2019-10-01 02:00:55.422733
# Epoch 6:
# 352
# Training loss: 0.9587, Training accuracy: 66.2533 %
# 2019-10-01 02:01:05.145248
# Validation...
# Validation loss: 0.8527, Validation accuracy: 70.2400 %
# Current learning rate has decayed to 0.007847
# Saving ...
# 2019-10-01 02:01:10.390247
# Epoch 7:
# 352
# Training loss: 0.9143, Training accuracy: 67.8133 %
# 2019-10-01 02:01:20.148249
# Validation...
# Validation loss: 0.7909, Validation accuracy: 72.1400 %
# Saving ...
# 2019-10-01 02:01:25.372247
# Epoch 8:
# 352
# Training loss: 0.8942, Training accuracy: 68.7156 %
# 2019-10-01 02:01:35.054248
# Validation...
# Validation loss: 0.8003, Validation accuracy: 71.6400 %
# Current learning rate has decayed to 0.007238
# 2019-10-01 02:01:40.239248
# Epoch 9:
# 352
# Training loss: 0.8696, Training accuracy: 69.4111 %
# 2019-10-01 02:01:49.938248
# Validation...
# Validation loss: 0.7775, Validation accuracy: 73.2400 %
# Saving ...
# 2019-10-01 02:01:55.449247
# Epoch 10:
# 352
# Training loss: 0.8540, Training accuracy: 69.7622 %
# 2019-10-01 02:02:05.144248
# Validation...
# Validation loss: 0.7595, Validation accuracy: 73.5000 %
# Current learning rate has decayed to 0.006676
# Saving ...
# 2019-10-01 02:02:10.519247
# Epoch 11:
# 352
# Training loss: 0.8298, Training accuracy: 70.7956 %
# 2019-10-01 02:02:20.233249
# Validation...
# Validation loss: 0.7409, Validation accuracy: 74.6400 %
# Saving ...
# 2019-10-01 02:02:25.635752
# Epoch 12:
# 352
# Training loss: 0.8177, Training accuracy: 71.4800 %
# 2019-10-01 02:02:35.302762
# Validation...
# Validation loss: 0.7230, Validation accuracy: 74.9200 %
# Current learning rate has decayed to 0.006158
# Saving ...
# 2019-10-01 02:02:40.575306
# Epoch 13:
# 352
# Training loss: 0.8008, Training accuracy: 71.8556 %
# 2019-10-01 02:02:50.249774
# Validation...
# Validation loss: 0.7282, Validation accuracy: 74.6800 %
# 2019-10-01 02:02:55.425775
# Epoch 14:
# 352
# Training loss: 0.7855, Training accuracy: 72.5044 %
# 2019-10-01 02:03:05.157774
# Validation...
# Validation loss: 0.7012, Validation accuracy: 75.3200 %
# Current learning rate has decayed to 0.005680
# Saving ...
# 2019-10-01 02:03:10.459796
# Epoch 15:
# 352
# Training loss: 0.7752, Training accuracy: 72.8822 %
# 2019-10-01 02:03:20.231796
# Validation...
# Validation loss: 0.7398, Validation accuracy: 74.7200 %
# 2019-10-01 02:03:25.373796
# Epoch 16:
# 352
# Training loss: 0.7615, Training accuracy: 73.3933 %
# 2019-10-01 02:03:35.231796
# Validation...
# Validation loss: 0.7200, Validation accuracy: 74.8400 %
# Current learning rate has decayed to 0.005239
# 2019-10-01 02:03:40.347797
# Epoch 17:
# 352
# Training loss: 0.7449, Training accuracy: 73.8267 %
# 2019-10-01 02:03:50.116798
# Validation...
# Validation loss: 0.6984, Validation accuracy: 76.3200 %
# Saving ...
# 2019-10-01 02:03:55.406978
# Epoch 18:
# 352
# Training loss: 0.7352, Training accuracy: 74.1400 %
# 2019-10-01 02:04:05.206981
# Validation...
# Validation loss: 0.6939, Validation accuracy: 75.9400 %
# Current learning rate has decayed to 0.004832
# 2019-10-01 02:04:10.322978
# Epoch 19:
# 352
# Training loss: 0.7323, Training accuracy: 74.3844 %
# 2019-10-01 02:04:20.095980
# Validation...
# Validation loss: 0.6963, Validation accuracy: 76.4000 %
# Saving ...
# 2019-10-01 02:04:25.376979
# Epoch 20:
# 352
# Training loss: 0.7244, Training accuracy: 74.9156 %
# 2019-10-01 02:04:35.119981
# Validation...
# Validation loss: 0.7026, Validation accuracy: 76.6000 %
# Current learning rate has decayed to 0.004457
# Saving ...
# 2019-10-01 02:04:40.386978
# Epoch 21:
# 352
# Training loss: 0.7077, Training accuracy: 75.3111 %
# 2019-10-01 02:04:50.151980
# Validation...
# Validation loss: 0.7043, Validation accuracy: 76.5600 %
# 2019-10-01 02:04:55.274980
# Epoch 22:
# 352
# Training loss: 0.7027, Training accuracy: 75.2267 %
# 2019-10-01 02:05:05.091979
# Validation...
# Validation loss: 0.7062, Validation accuracy: 76.4000 %
# Current learning rate has decayed to 0.004111
# 2019-10-01 02:05:10.215980
# Epoch 23:
# 352
# Training loss: 0.6877, Training accuracy: 75.9044 %
# 2019-10-01 02:05:19.946979
# Validation...
# Validation loss: 0.6895, Validation accuracy: 77.1600 %
# Saving ...
# 2019-10-01 02:05:25.187979
# Epoch 24:
# 352
# Training loss: 0.6839, Training accuracy: 76.0378 %
# 2019-10-01 02:05:34.909004
# Validation...
# Validation loss: 0.6799, Validation accuracy: 76.9200 %
# Current learning rate has decayed to 0.003792
# 2019-10-01 02:05:40.133002
# Epoch 25:
# 352
# Training loss: 0.6749, Training accuracy: 76.5778 %
# 2019-10-01 02:05:49.824005
# Validation...
# Validation loss: 0.6869, Validation accuracy: 76.7200 %
# 2019-10-01 02:05:55.040003
# Epoch 26:
# 352
# Training loss: 0.6676, Training accuracy: 76.5622 %
# 2019-10-01 02:06:04.728518
# Validation...
# Validation loss: 0.6866, Validation accuracy: 76.6600 %
# Current learning rate has decayed to 0.003497
# 2019-10-01 02:06:09.944518
# Epoch 27:
# 352
# Training loss: 0.6599, Training accuracy: 77.0778 %
# 2019-10-01 02:06:19.587519
# Validation...
# Validation loss: 0.6673, Validation accuracy: 77.0600 %
# 2019-10-01 02:06:24.890518
# Epoch 28:
# 352
# Training loss: 0.6586, Training accuracy: 76.8444 %
# 2019-10-01 02:06:34.555518
# Validation...
# Validation loss: 0.6689, Validation accuracy: 77.4600 %
# Current learning rate has decayed to 0.003226
# Saving ...
# 2019-10-01 02:06:39.939726
# Epoch 29:
# 352
# Training loss: 0.6502, Training accuracy: 77.5867 %
# 2019-10-01 02:06:49.630731
# Validation...
# Validation loss: 0.6793, Validation accuracy: 77.1800 %
# 2019-10-01 02:06:54.800731
# Epoch 30:
# 352
# Training loss: 0.6461, Training accuracy: 77.7111 %
# 2019-10-01 02:07:04.537732
# Validation...
# Validation loss: 0.6672, Validation accuracy: 77.9400 %
# Current learning rate has decayed to 0.002976
# Saving ...
# 2019-10-01 02:07:09.853732
# Epoch 31:
# 352
# Training loss: 0.6371, Training accuracy: 77.8644 %
# 2019-10-01 02:07:19.714244
# Validation...
# Validation loss: 0.6697, Validation accuracy: 77.4600 %
# 2019-10-01 02:07:24.883244
# Epoch 32:
# 352
# Training loss: 0.6356, Training accuracy: 78.0711 %
# 2019-10-01 02:07:34.632758
# Validation...
# Validation loss: 0.6602, Validation accuracy: 77.3800 %
# Current learning rate has decayed to 0.002745
# 2019-10-01 02:07:39.828758
# Epoch 33:
# 352
# Training loss: 0.6296, Training accuracy: 78.1067 %
# 2019-10-01 02:07:49.646757
# Validation...
# Validation loss: 0.6583, Validation accuracy: 77.4800 %
# 2019-10-01 02:07:54.793759
# Epoch 34:
# 352
# Training loss: 0.6278, Training accuracy: 78.6467 %
# 2019-10-01 02:08:04.552758
# Validation...
# Validation loss: 0.6668, Validation accuracy: 77.2400 %
# Current learning rate has decayed to 0.002531
# 2019-10-01 02:08:09.684786
# Epoch 35:
# 352
# Training loss: 0.6138, Training accuracy: 78.9356 %
# 2019-10-01 02:08:19.507787
# Validation...
# Validation loss: 0.6497, Validation accuracy: 78.4200 %
# Saving ...
# 2019-10-01 02:08:24.785786
# Epoch 36:
# 352
# Training loss: 0.6159, Training accuracy: 78.9356 %
# 2019-10-01 02:08:34.523786
# Validation...
# Validation loss: 0.6523, Validation accuracy: 77.6800 %
# Current learning rate has decayed to 0.002335
# 2019-10-01 02:08:39.646786
# Epoch 37:
# 352
# Training loss: 0.6081, Training accuracy: 79.0756 %
# 2019-10-01 02:08:49.350786
# Validation...
# Validation loss: 0.6621, Validation accuracy: 77.9600 %
# 2019-10-01 02:08:54.474784
# Epoch 38:
# 352
# Training loss: 0.6093, Training accuracy: 79.0600 %
# 2019-10-01 02:09:04.167785
# Validation...
# Validation loss: 0.6563, Validation accuracy: 78.3400 %
# Current learning rate has decayed to 0.002154
# 2019-10-01 02:09:09.307787
# Epoch 39:
# 352
# Training loss: 0.6002, Training accuracy: 79.2444 %
# 2019-10-01 02:09:19.021786
# Validation...
# Validation loss: 0.6392, Validation accuracy: 78.4600 %
# Saving ...
# 2019-10-01 02:09:26.844770
# Epoch 40:
# 352
# Training loss: 0.5982, Training accuracy: 79.6622 %
# 2019-10-01 02:09:36.605771
# Validation...
# Validation loss: 0.6551, Validation accuracy: 78.3800 %
# Current learning rate has decayed to 0.001986
# 2019-10-01 02:09:41.700772
# Epoch 41:
# 352
# Training loss: 0.5945, Training accuracy: 79.6089 %
# 2019-10-01 02:09:51.440770
# Validation...
# Validation loss: 0.6482, Validation accuracy: 78.1600 %
# 2019-10-01 02:09:56.592281
# Epoch 42:
# 352
# Training loss: 0.5872, Training accuracy: 79.9422 %
# 2019-10-01 02:10:06.387281
# Validation...
# Validation loss: 0.6488, Validation accuracy: 78.2400 %
# Current learning rate has decayed to 0.001832
# 2019-10-01 02:10:11.578280
# Epoch 43:
# 352
# Training loss: 0.5846, Training accuracy: 79.9400 %
# 2019-10-01 02:10:21.310280
# Validation...
# Validation loss: 0.6560, Validation accuracy: 77.8400 %
# 2019-10-01 02:10:26.494280
# Epoch 44:
# 352
# Training loss: 0.5765, Training accuracy: 80.2756 %
# 2019-10-01 02:10:36.231280
# Validation...
# Validation loss: 0.6620, Validation accuracy: 77.9000 %
# Current learning rate has decayed to 0.001690
# 2019-10-01 02:10:41.491282
# Epoch 45:
# 352
# Training loss: 0.5725, Training accuracy: 80.5756 %
# 2019-10-01 02:10:51.179281
# Validation...
# Validation loss: 0.6508, Validation accuracy: 78.4800 %
# Saving ...
# 2019-10-01 02:10:56.525066
# Epoch 46:
# 352
# Training loss: 0.5754, Training accuracy: 80.2711 %
# 2019-10-01 02:11:06.342067
# Validation...
# Validation loss: 0.6578, Validation accuracy: 78.3000 %
# Current learning rate has decayed to 0.001559
# 2019-10-01 02:11:11.497066
# Epoch 47:
# 352
# Training loss: 0.5772, Training accuracy: 80.3778 %
# 2019-10-01 02:11:21.168066
# Validation...
# Validation loss: 0.6495, Validation accuracy: 78.2200 %
# 2019-10-01 02:11:26.302802
# Epoch 48:
# 352
# Training loss: 0.5703, Training accuracy: 80.8822 %
# 2019-10-01 02:11:36.083800
# Validation...
# Validation loss: 0.6512, Validation accuracy: 78.1800 %
# Current learning rate has decayed to 0.001438
# 2019-10-01 02:11:41.224800
# Epoch 49:
# 352
# Training loss: 0.5668, Training accuracy: 80.7244 %
# 2019-10-01 02:11:51.052801
# Validation...
# Validation loss: 0.6532, Validation accuracy: 78.4400 %
# 2019-10-01 02:11:56.172801
# Epoch 50:
# 352
# Training loss: 0.5558, Training accuracy: 81.0244 %
# 2019-10-01 02:12:05.954825
# Validation...
# Validation loss: 0.6430, Validation accuracy: 78.7200 %
# Current learning rate has decayed to 0.001326
# Saving ...
# 2019-10-01 02:12:11.180824
# Epoch 51:
# 352
# Training loss: 0.5518, Training accuracy: 81.2911 %
# 2019-10-01 02:12:21.031825
# Validation...
# Validation loss: 0.6395, Validation accuracy: 78.7400 %
# Saving ...
# 2019-10-01 02:12:26.289824
# Epoch 52:
# 352
# Training loss: 0.5554, Training accuracy: 81.4289 %
# 2019-10-01 02:12:36.074824
# Validation...
# Validation loss: 0.6409, Validation accuracy: 78.4400 %
# Current learning rate has decayed to 0.001223
# 2019-10-01 02:12:41.192825
# Epoch 53:
# 352
# Training loss: 0.5484, Training accuracy: 81.4667 %
# 2019-10-01 02:12:50.885825
# Validation...
# Validation loss: 0.6490, Validation accuracy: 78.3400 %
# 2019-10-01 02:12:56.022824
# Epoch 54:
# 352
# Training loss: 0.5460, Training accuracy: 81.5467 %
# 2019-10-01 02:13:05.770372
# Validation...
# Validation loss: 0.6363, Validation accuracy: 79.0200 %
# Current learning rate has decayed to 0.001128
# Saving ...
# 2019-10-01 02:13:11.021630
# Epoch 55:
# 352
# Training loss: 0.5443, Training accuracy: 81.6689 %
# 2019-10-01 02:13:20.766632
# Validation...
# Validation loss: 0.6476, Validation accuracy: 78.6400 %
# 2019-10-01 02:13:25.881630
# Epoch 56:
# 352
# Training loss: 0.5410, Training accuracy: 81.9511 %
# 2019-10-01 02:13:35.572631
# Validation...
# Validation loss: 0.6462, Validation accuracy: 78.4200 %
# Current learning rate has decayed to 0.001041
# 2019-10-01 02:13:40.769631
# Epoch 57:
# 352
# Training loss: 0.5391, Training accuracy: 81.6933 %
# 2019-10-01 02:13:50.559631
# Validation...
# Validation loss: 0.6366, Validation accuracy: 78.9600 %
# 2019-10-01 02:13:55.887631
# Epoch 58:
# 352
# Training loss: 0.5371, Training accuracy: 81.9289 %
# 2019-10-01 02:14:05.597148
# Validation...
# Validation loss: 0.6418, Validation accuracy: 78.6600 %
# Current learning rate has decayed to 0.000960
# 2019-10-01 02:14:10.764148
# Epoch 59:
# 352
# Training loss: 0.5349, Training accuracy: 82.0089 %
# 2019-10-01 02:14:20.456147
# Validation...
# Validation loss: 0.6382, Validation accuracy: 78.9000 %
# 2019-10-01 02:14:25.659148
# Epoch 60:
# 352
# Training loss: 0.5356, Training accuracy: 81.8311 %
# 2019-10-01 02:14:35.384978
# Validation...
# Validation loss: 0.6509, Validation accuracy: 78.6600 %
# Current learning rate has decayed to 0.000885
# 2019-10-01 02:14:40.600978
# Epoch 61:
# 352
# Training loss: 0.5285, Training accuracy: 82.4222 %
# 2019-10-01 02:14:50.290976
# Validation...
# Validation loss: 0.6469, Validation accuracy: 78.9600 %
# 2019-10-01 02:14:55.478002
# Epoch 62:
# 352
# Training loss: 0.5281, Training accuracy: 82.3756 %
# 2019-10-01 02:15:05.184032
# Validation...
# Validation loss: 0.6469, Validation accuracy: 78.9000 %
# Current learning rate has decayed to 0.000817
# 2019-10-01 02:15:10.345034
# Epoch 63:
# 352
# Training loss: 0.5281, Training accuracy: 82.2133 %
# 2019-10-01 02:15:20.071032
# Validation...
# Validation loss: 0.6466, Validation accuracy: 78.8800 %
# 2019-10-01 02:15:25.256033
# Epoch 64:
# 352
# Training loss: 0.5253, Training accuracy: 82.3489 %
# 2019-10-01 02:15:35.037067
# Validation...
# Validation loss: 0.6429, Validation accuracy: 78.8200 %
# Current learning rate has decayed to 0.000753
# 2019-10-01 02:15:40.175066
# Epoch 65:
# 352
# Training loss: 0.5199, Training accuracy: 82.6644 %
# 2019-10-01 02:15:49.938066
# Validation...
# Validation loss: 0.6352, Validation accuracy: 78.6200 %
# 2019-10-01 02:15:55.092066
# Epoch 66:
# 352
# Training loss: 0.5201, Training accuracy: 82.6111 %
# 2019-10-01 02:16:04.771065
# Validation...
# Validation loss: 0.6498, Validation accuracy: 78.9600 %
# Current learning rate has decayed to 0.000695
# 2019-10-01 02:16:09.903066
# Epoch 67:
# 352
# Training loss: 0.5174, Training accuracy: 82.8200 %
# 2019-10-01 02:16:19.650065
# Validation...
# Validation loss: 0.6403, Validation accuracy: 78.7600 %
# 2019-10-01 02:16:24.784068
# Epoch 68:
# 352
# Training loss: 0.5116, Training accuracy: 82.7600 %
# 2019-10-01 02:16:34.541582
# Validation...
# Validation loss: 0.6348, Validation accuracy: 78.9400 %
# Current learning rate has decayed to 0.000641
# 2019-10-01 02:16:39.643581
# Epoch 69:
# 352
# Training loss: 0.5065, Training accuracy: 82.9022 %
# 2019-10-01 02:16:49.374582
# Validation...
# Validation loss: 0.6437, Validation accuracy: 79.1600 %
# Saving ...
# 2019-10-01 02:16:54.600581
# Epoch 70:
# 352
# Training loss: 0.5113, Training accuracy: 83.0600 %
# 2019-10-01 02:17:04.315124
# Validation...
# Validation loss: 0.6402, Validation accuracy: 79.0000 %
# Current learning rate has decayed to 0.000591
# 2019-10-01 02:17:09.400126
# Epoch 71:
# 352
# Training loss: 0.5049, Training accuracy: 83.2244 %
# 2019-10-01 02:17:19.099663
# Validation...
# Validation loss: 0.6459, Validation accuracy: 78.7800 %
# 2019-10-01 02:17:24.275662
# Epoch 72:
# 352
# Training loss: 0.5058, Training accuracy: 82.9444 %
# 2019-10-01 02:17:33.964688
# Validation...
# Validation loss: 0.6485, Validation accuracy: 78.8800 %
# Current learning rate has decayed to 0.000545
# 2019-10-01 02:17:39.245687
# Epoch 73:
# 352
# Training loss: 0.5020, Training accuracy: 83.4867 %
# 2019-10-01 02:17:49.018712
# Validation...
# Validation loss: 0.6466, Validation accuracy: 78.9400 %
# 2019-10-01 02:17:54.198711
# Epoch 74:
# 352
# Training loss: 0.5057, Training accuracy: 83.1889 %
# 2019-10-01 02:18:03.865710
# Validation...
# Validation loss: 0.6400, Validation accuracy: 79.0600 %
# Current learning rate has decayed to 0.000503
# 2019-10-01 02:18:09.072711
# Epoch 75:
# 352
# Training loss: 0.4996, Training accuracy: 83.3356 %
# 2019-10-01 02:18:18.843712
# Validation...
# Validation loss: 0.6469, Validation accuracy: 78.3600 %
# 2019-10-01 02:18:24.030711
# Epoch 76:
# 352
# Training loss: 0.5022, Training accuracy: 83.3511 %
# 2019-10-01 02:18:33.767223
# Validation...
# Validation loss: 0.6482, Validation accuracy: 78.6800 %
# Current learning rate has decayed to 0.000464
# 2019-10-01 02:18:38.884226
# Epoch 77:
# 352
# Training loss: 0.5061, Training accuracy: 83.2244 %
# 2019-10-01 02:18:48.591736
# Validation...
# Validation loss: 0.6473, Validation accuracy: 78.8400 %
# 2019-10-01 02:18:53.695737
# Epoch 78:
# 352
# Training loss: 0.4932, Training accuracy: 83.8089 %
# 2019-10-01 02:19:03.448738
# Validation...
# Validation loss: 0.6426, Validation accuracy: 78.6800 %
# Current learning rate has decayed to 0.000428
# 2019-10-01 02:19:08.565739
# Epoch 79:
# 352
# Training loss: 0.4948, Training accuracy: 83.7000 %
# 2019-10-01 02:19:18.321278
# Validation...
# Validation loss: 0.6436, Validation accuracy: 79.3800 %
# Saving ...
# 2019-10-01 02:19:23.548278
# Epoch 80:
# 352
# Training loss: 0.4884, Training accuracy: 83.8378 %
# 2019-10-01 02:19:33.302277
# Validation...
# Validation loss: 0.6458, Validation accuracy: 79.3600 %
# Current learning rate has decayed to 0.000395
# 2019-10-01 02:19:38.512280
# Epoch 81:
# 352
# Training loss: 0.4872, Training accuracy: 83.9111 %
# 2019-10-01 02:19:48.306791
# Validation...
# Validation loss: 0.6462, Validation accuracy: 78.7800 %
# 2019-10-01 02:19:53.421791
# Epoch 82:
# 352
# Training loss: 0.4866, Training accuracy: 83.9667 %
# 2019-10-01 02:20:03.155791
# Validation...
# Validation loss: 0.6417, Validation accuracy: 79.2400 %
# Current learning rate has decayed to 0.000364
# 2019-10-01 02:20:08.291792
# Epoch 83:
# 352
# Training loss: 0.4875, Training accuracy: 83.9444 %
# 2019-10-01 02:20:18.052817
# Validation...
# Validation loss: 0.6424, Validation accuracy: 78.9000 %
# 2019-10-01 02:20:23.189818
# Epoch 84:
# 352
# Training loss: 0.4908, Training accuracy: 83.8911 %
# 2019-10-01 02:20:32.919842
# Validation...
# Validation loss: 0.6430, Validation accuracy: 78.8200 %
# Current learning rate has decayed to 0.000336
# 2019-10-01 02:20:38.028842
# Epoch 85:
# 352
# Training loss: 0.4867, Training accuracy: 83.9044 %
# 2019-10-01 02:20:47.809869
# Validation...
# Validation loss: 0.6382, Validation accuracy: 79.2200 %
# 2019-10-01 02:20:52.925868
# Epoch 86:
# 352
# Training loss: 0.4867, Training accuracy: 84.1244 %
# 2019-10-01 02:21:02.633893
# Validation...
# Validation loss: 0.6373, Validation accuracy: 79.5200 %
# Current learning rate has decayed to 0.000310
# Saving ...
# 2019-10-01 02:21:08.037893
# Epoch 87:
# 352
# Training loss: 0.4790, Training accuracy: 84.1867 %
# 2019-10-01 02:21:17.739920
# Validation...
# Validation loss: 0.6358, Validation accuracy: 79.0400 %
# 2019-10-01 02:21:22.953918
# Epoch 88:
# 352
# Training loss: 0.4720, Training accuracy: 84.4711 %
# 2019-10-01 02:21:32.677939
# Validation...
# Validation loss: 0.6416, Validation accuracy: 79.3000 %
# Current learning rate has decayed to 0.000286
# 2019-10-01 02:21:37.849941
# Epoch 89:
# 352
# Training loss: 0.4801, Training accuracy: 84.3511 %
# 2019-10-01 02:21:47.565964
# Validation...
# Validation loss: 0.6353, Validation accuracy: 79.4600 %
# 2019-10-01 02:21:52.915964
# Epoch 90:
# 352
# Training loss: 0.4858, Training accuracy: 84.2267 %
# 2019-10-01 02:22:02.585478
# Validation...
# Validation loss: 0.6406, Validation accuracy: 79.4400 %
# Current learning rate has decayed to 0.000263
# 2019-10-01 02:22:07.824477
# Epoch 91:
# 352
# Training loss: 0.4720, Training accuracy: 84.4911 %
# 2019-10-01 02:22:17.506503
# Validation...
# Validation loss: 0.6351, Validation accuracy: 79.5000 %
# 2019-10-01 02:22:22.661502
# Epoch 92:
# 352
# Training loss: 0.4777, Training accuracy: 84.5956 %
# 2019-10-01 02:22:32.457526
# Validation...
# Validation loss: 0.6363, Validation accuracy: 79.4400 %
# Current learning rate has decayed to 0.000243
# 2019-10-01 02:22:37.591527
# Epoch 93:
# 352
# Training loss: 0.4748, Training accuracy: 84.7044 %
# 2019-10-01 02:22:47.346527
# Validation...
# Validation loss: 0.6353, Validation accuracy: 79.3000 %
# 2019-10-01 02:22:52.494527
# Epoch 94:
# 352
# Training loss: 0.4765, Training accuracy: 84.4156 %
# 2019-10-01 02:23:02.356528
# Validation...
# Validation loss: 0.6360, Validation accuracy: 79.5000 %
# Current learning rate has decayed to 0.000224
# 2019-10-01 02:23:07.499527
# Epoch 95:
# 352
# Training loss: 0.4751, Training accuracy: 84.7000 %
# 2019-10-01 02:23:17.270526
# Validation...
# Validation loss: 0.6414, Validation accuracy: 79.1000 %
# 2019-10-01 02:23:22.407530
# Epoch 96:
# 352
# Training loss: 0.4714, Training accuracy: 84.4378 %
# 2019-10-01 02:23:32.275528
# Validation...
# Validation loss: 0.6357, Validation accuracy: 79.5000 %
# Current learning rate has decayed to 0.000207
# 2019-10-01 02:23:37.458731
# Epoch 97:
# 352
# Training loss: 0.4676, Training accuracy: 84.5667 %
# 2019-10-01 02:23:47.154730
# Validation...
# Validation loss: 0.6373, Validation accuracy: 79.5600 %
# Saving ...
# 2019-10-01 02:23:52.435696
# Epoch 98:
# 352
# Training loss: 0.4702, Training accuracy: 84.5733 %
# 2019-10-01 02:24:02.226696
# Validation...
# Validation loss: 0.6320, Validation accuracy: 79.0800 %
# Current learning rate has decayed to 0.000191
# 2019-10-01 02:24:07.339696
# Epoch 99:
# 352
# Training loss: 0.4663, Training accuracy: 84.9867 %
# 2019-10-01 02:24:17.107697
# Validation...
# Validation loss: 0.6343, Validation accuracy: 79.1600 %
# 2019-10-01 02:24:22.442695
# Epoch 100:
# 352
# Training loss: 0.4613, Training accuracy: 85.0000 %
# 2019-10-01 02:24:32.224696
# Validation...
# Validation loss: 0.6362, Validation accuracy: 79.0200 %
# Current learning rate has decayed to 0.000176
# 2019-10-01 02:24:37.339695
# Epoch 101:
# 352
# Training loss: 0.4676, Training accuracy: 84.5911 %
# 2019-10-01 02:24:47.030696
# Validation...
# Validation loss: 0.6357, Validation accuracy: 79.0400 %
# 2019-10-01 02:24:52.261696
# Epoch 102:
# 352
# Training loss: 0.4661, Training accuracy: 84.8089 %
# 2019-10-01 02:25:02.010696
# Validation...
# Validation loss: 0.6391, Validation accuracy: 79.1800 %
# Current learning rate has decayed to 0.000162
# 2019-10-01 02:25:07.292697
# Epoch 103:
# 352
# Training loss: 0.4780, Training accuracy: 84.4911 %
# 2019-10-01 02:25:16.982697
# Validation...
# Validation loss: 0.6358, Validation accuracy: 78.8200 %
# 2019-10-01 02:25:22.187697
# Epoch 104:
# 352
# Training loss: 0.4678, Training accuracy: 84.7622 %
# 2019-10-01 02:25:31.951697
# Validation...
# Validation loss: 0.6353, Validation accuracy: 79.0000 %
# Current learning rate has decayed to 0.000150
# 2019-10-01 02:25:37.161697
# Epoch 105:
# 352
# Training loss: 0.4663, Training accuracy: 85.0200 %
# 2019-10-01 02:25:46.857209
# Validation...
# Validation loss: 0.6376, Validation accuracy: 79.2600 %
# 2019-10-01 02:25:52.087209
# Epoch 106:
# 352
# Training loss: 0.4656, Training accuracy: 85.0289 %
# 2019-10-01 02:26:01.831209
# Validation...
# Validation loss: 0.6455, Validation accuracy: 78.8800 %
# Current learning rate has decayed to 0.000138
# 2019-10-01 02:26:07.026211
# Epoch 107:
# 352
# Training loss: 0.4657, Training accuracy: 84.9622 %
# 2019-10-01 02:26:16.769209
# Validation...
# Validation loss: 0.6352, Validation accuracy: 79.0600 %
# 2019-10-01 02:26:21.930223
# Epoch 108:
# 352
# Training loss: 0.4563, Training accuracy: 85.2800 %
# 2019-10-01 02:26:31.759223
# Validation...
# Validation loss: 0.6393, Validation accuracy: 79.1400 %
# Current learning rate has decayed to 0.000127
# 2019-10-01 02:26:36.897226
# Epoch 109:
# 352
# Training loss: 0.4526, Training accuracy: 85.3511 %
# 2019-10-01 02:26:46.599224
# Validation...
# Validation loss: 0.6343, Validation accuracy: 79.4200 %
# 2019-10-01 02:26:51.738224
# Epoch 110:
# 352
# Training loss: 0.4577, Training accuracy: 84.8711 %
# 2019-10-01 02:27:01.597224
# Validation...
# Validation loss: 0.6318, Validation accuracy: 79.0200 %
# Current learning rate has decayed to 0.000117
# 2019-10-01 02:27:06.678223
# Epoch 111:
# 352
# Training loss: 0.4540, Training accuracy: 85.4000 %
# 2019-10-01 02:27:16.442225
# Validation...
# Validation loss: 0.6308, Validation accuracy: 79.3800 %
# 2019-10-01 02:27:21.541224
# Epoch 112:
# 352
# Training loss: 0.4528, Training accuracy: 85.2889 %
# 2019-10-01 02:27:31.241222
# Validation...
# Validation loss: 0.6351, Validation accuracy: 78.9000 %
# Current learning rate has decayed to 0.000108
# 2019-10-01 02:27:36.337223
# Epoch 113:
# 352
# Training loss: 0.4596, Training accuracy: 85.0778 %
# 2019-10-01 02:27:46.049222
# Validation...
# Validation loss: 0.6343, Validation accuracy: 79.2200 %
# 2019-10-01 02:27:51.187222
# Epoch 114:
# 352
# Training loss: 0.4525, Training accuracy: 85.4000 %
# 2019-10-01 02:28:00.986222
# Validation...
# Validation loss: 0.6389, Validation accuracy: 78.9000 %
# Current learning rate has decayed to 0.000100
# 2019-10-01 02:28:06.077224
# Epoch 115:
# 352
# Training loss: 0.4538, Training accuracy: 85.3533 %
# 2019-10-01 02:28:15.801224
# Validation...
# Validation loss: 0.6313, Validation accuracy: 78.9800 %
# 2019-10-01 02:28:20.920222
# Epoch 116:
# 352
# Training loss: 0.4518, Training accuracy: 85.2911 %
# 2019-10-01 02:28:30.597224
# Validation...
# Validation loss: 0.6368, Validation accuracy: 79.1400 %
# Current learning rate has decayed to 0.000092
# 2019-10-01 02:28:35.844224
# Epoch 117:
# 352
# Training loss: 0.4479, Training accuracy: 85.4000 %
# 2019-10-01 02:28:45.631222
# Validation...
# Validation loss: 0.6384, Validation accuracy: 79.2400 %
# 2019-10-01 02:28:50.819223
# Epoch 118:
# 352
# Training loss: 0.4515, Training accuracy: 85.5778 %
# 2019-10-01 02:29:00.562223
# Validation...
# Validation loss: 0.6311, Validation accuracy: 79.2200 %
# Current learning rate has decayed to 0.000085
# 2019-10-01 02:29:05.729223
# Epoch 119:
# 352
# Training loss: 0.4485, Training accuracy: 85.2222 %
# 2019-10-01 02:29:15.400223
# Validation...
# Validation loss: 0.6325, Validation accuracy: 79.2200 %
# 2019-10-01 02:29:20.625225
# Epoch 120:
# 352
# Training loss: 0.4565, Training accuracy: 85.5111 %
# 2019-10-01 02:29:30.301223
# Validation...
# Validation loss: 0.6342, Validation accuracy: 79.4000 %
# Current learning rate has decayed to 0.000078
# 2019-10-01 02:29:35.439225
# Epoch 121:
# 352
# Training loss: 0.4505, Training accuracy: 85.3178 %
# 2019-10-01 02:29:45.122224
# Validation...
# Validation loss: 0.6338, Validation accuracy: 79.1400 %
# 2019-10-01 02:29:50.224223
# Epoch 122:
# 352
# Training loss: 0.4415, Training accuracy: 85.6111 %
# 2019-10-01 02:29:59.965223
# Validation...
# Validation loss: 0.6290, Validation accuracy: 79.6800 %
# Current learning rate has decayed to 0.000072
# Saving ...
# 2019-10-01 02:30:05.318028
# Epoch 123:
# 352
# Training loss: 0.4536, Training accuracy: 85.3578 %
# 2019-10-01 02:30:15.062036
# Validation...
# Validation loss: 0.6318, Validation accuracy: 79.4800 %
# 2019-10-01 02:30:20.204029
# Epoch 124:
# 352
# Training loss: 0.4477, Training accuracy: 85.7222 %
# 2019-10-01 02:30:29.922029
# Validation...
# Validation loss: 0.6320, Validation accuracy: 79.4600 %
# Current learning rate has decayed to 0.000067
# 2019-10-01 02:30:35.039030
# Epoch 125:
# 352
# Training loss: 0.4411, Training accuracy: 85.6400 %
# 2019-10-01 02:30:44.964031
# Validation...
# Validation loss: 0.6265, Validation accuracy: 79.4200 %
# 2019-10-01 02:30:50.078029
# Epoch 126:
# 352
# Training loss: 0.4447, Training accuracy: 85.7289 %
# 2019-10-01 02:30:59.803030
# Validation...
# Validation loss: 0.6321, Validation accuracy: 79.4200 %
# Current learning rate has decayed to 0.000062
# 2019-10-01 02:31:04.919029
# Epoch 127:
# 352
# Training loss: 0.4407, Training accuracy: 85.8289 %
# 2019-10-01 02:31:14.703029
# Validation...
# Validation loss: 0.6307, Validation accuracy: 79.2400 %
# 2019-10-01 02:31:19.841030
# Epoch 128:
# 352
# Training loss: 0.4440, Training accuracy: 85.6889 %
# 2019-10-01 02:31:29.549028
# Validation...
# Validation loss: 0.6289, Validation accuracy: 79.3400 %
# Current learning rate has decayed to 0.000057
# 2019-10-01 02:31:34.656031
# Epoch 129:
# 352
# Training loss: 0.4421, Training accuracy: 85.7667 %
# 2019-10-01 02:31:44.412032
# Validation...
# Validation loss: 0.6293, Validation accuracy: 79.7600 %
# Saving ...
# 2019-10-01 02:31:49.678029
# Epoch 130:
# 352
# Training loss: 0.4367, Training accuracy: 86.0178 %
# 2019-10-01 02:31:59.421031
# Validation...
# Validation loss: 0.6362, Validation accuracy: 79.2400 %
# Current learning rate has decayed to 0.000052
# 2019-10-01 02:32:04.575030
# Epoch 131:
# 352
# Training loss: 0.4511, Training accuracy: 85.5644 %
# 2019-10-01 02:32:14.284029
# Validation...
# Validation loss: 0.6328, Validation accuracy: 79.5800 %
# 2019-10-01 02:32:19.545028
# Epoch 132:
# 352
# Training loss: 0.4417, Training accuracy: 85.8244 %
# 2019-10-01 02:32:29.257029
# Validation...
# Validation loss: 0.6323, Validation accuracy: 79.2200 %
# Current learning rate has decayed to 0.000048
# 2019-10-01 02:32:34.467029
# Epoch 133:
# 352
# Training loss: 0.4426, Training accuracy: 85.8000 %
# 2019-10-01 02:32:44.146029
# Validation...
# Validation loss: 0.6316, Validation accuracy: 79.3600 %
# 2019-10-01 02:32:49.374030
# Epoch 134:
# 352
# Training loss: 0.4459, Training accuracy: 85.7622 %
# 2019-10-01 02:32:59.049030
# Validation...
# Validation loss: 0.6372, Validation accuracy: 79.5200 %
# Current learning rate has decayed to 0.000045
# 2019-10-01 02:33:04.309031
# Epoch 135:
# 352
# Training loss: 0.4397, Training accuracy: 85.7822 %
# 2019-10-01 02:33:14.055028
# Validation...
# Validation loss: 0.6336, Validation accuracy: 79.2400 %
# 2019-10-01 02:33:19.241033
# Epoch 136:
# 352
# Training loss: 0.4507, Training accuracy: 85.7156 %
# 2019-10-01 02:33:28.900029
# Validation...
# Validation loss: 0.6309, Validation accuracy: 79.7600 %
# Current learning rate has decayed to 0.000041
# 2019-10-01 02:33:34.035072
# Epoch 137:
# 352
# Training loss: 0.4451, Training accuracy: 85.6844 %
# 2019-10-01 02:33:43.832030
# Validation...
# Validation loss: 0.6314, Validation accuracy: 79.1800 %
# 2019-10-01 02:33:48.979031
# Epoch 138:
# 352
# Training loss: 0.4347, Training accuracy: 86.0178 %
# 2019-10-01 02:33:58.734029
# Validation...
# Validation loss: 0.6297, Validation accuracy: 79.4200 %
# Current learning rate has decayed to 0.000038
# 2019-10-01 02:34:03.885031
# Epoch 139:
# 352
# Training loss: 0.4377, Training accuracy: 85.9822 %
# 2019-10-01 02:34:13.620029
# Validation...
# Validation loss: 0.6304, Validation accuracy: 79.3000 %
# 2019-10-01 02:34:18.717030
# Epoch 140:
# 352
# Training loss: 0.4425, Training accuracy: 85.7689 %
# 2019-10-01 02:34:28.465030
# Validation...
# Validation loss: 0.6332, Validation accuracy: 79.3400 %
# Current learning rate has decayed to 0.000035
# 2019-10-01 02:34:33.604030
# Epoch 141:
# 352
# Training loss: 0.4420, Training accuracy: 85.8933 %
# 2019-10-01 02:34:43.486030
# Validation...
# Validation loss: 0.6330, Validation accuracy: 79.1400 %
# 2019-10-01 02:34:48.620030
# Epoch 142:
# 352
# Training loss: 0.4348, Training accuracy: 86.1889 %
# 2019-10-01 02:34:58.343029
# Validation...
# Validation loss: 0.6364, Validation accuracy: 79.1800 %
# Current learning rate has decayed to 0.000032
# 2019-10-01 02:35:03.441030
# Epoch 143:
# 352
# Training loss: 0.4384, Training accuracy: 85.8467 %
# 2019-10-01 02:35:13.252030
# Validation...
# Validation loss: 0.6309, Validation accuracy: 79.6400 %
# 2019-10-01 02:35:18.352029
# Epoch 144:
# 352
# Training loss: 0.4320, Training accuracy: 86.0111 %
# 2019-10-01 02:35:28.080029
# Validation...
# Validation loss: 0.6344, Validation accuracy: 79.5400 %
# Current learning rate has decayed to 0.000030
# 2019-10-01 02:35:33.174029
# Epoch 145:
# 352
# Training loss: 0.4363, Training accuracy: 86.1000 %
# 2019-10-01 02:35:42.879029
# Validation...
# Validation loss: 0.6320, Validation accuracy: 79.4600 %
# 2019-10-01 02:35:48.123029
# Epoch 146:
# 352
# Training loss: 0.4366, Training accuracy: 86.0400 %
# 2019-10-01 02:35:57.833030
# Validation...
# Validation loss: 0.6321, Validation accuracy: 79.1400 %
# Current learning rate has decayed to 0.000027
# 2019-10-01 02:36:02.982028
# Epoch 147:
# 352
# Training loss: 0.4340, Training accuracy: 86.1267 %
# 2019-10-01 02:36:12.703028
# Validation...
# Validation loss: 0.6295, Validation accuracy: 79.1800 %
# 2019-10-01 02:36:17.868029
# Epoch 148:
# 352
# Training loss: 0.4357, Training accuracy: 85.8844 %
# 2019-10-01 02:36:27.606030
# Validation...
# Validation loss: 0.6303, Validation accuracy: 79.6000 %
# Current learning rate has decayed to 0.000025
# 2019-10-01 02:36:32.894030
# Epoch 149:
# 352
# Training loss: 0.4362, Training accuracy: 85.8667 %
# 2019-10-01 02:36:42.564030
# Validation...
# Validation loss: 0.6276, Validation accuracy: 79.5800 %
# 2019-10-01 02:36:47.724029
# Epoch 150:
# 352
# Training loss: 0.4322, Training accuracy: 85.9356 %
# 2019-10-01 02:36:57.444029
# Validation...
# Validation loss: 0.6297, Validation accuracy: 79.5600 %
# Current learning rate has decayed to 0.000023
# 2019-10-01 02:37:02.564029
# Epoch 151:
# 352
# Training loss: 0.4338, Training accuracy: 86.1689 %
# 2019-10-01 02:37:12.465029
# Validation...
# Validation loss: 0.6283, Validation accuracy: 79.7000 %
# 2019-10-01 02:37:17.566029
# Epoch 152:
# 352
# Training loss: 0.4324, Training accuracy: 86.1911 %
# 2019-10-01 02:37:27.282030
# Validation...
# Validation loss: 0.6301, Validation accuracy: 79.6400 %
# Current learning rate has decayed to 0.000022
# 2019-10-01 02:37:32.411030
# Epoch 153:
# 352
# Training loss: 0.4363, Training accuracy: 86.1267 %
# 2019-10-01 02:37:42.148029
# Validation...
# Validation loss: 0.6295, Validation accuracy: 80.0800 %
# Saving ...
# 2019-10-01 02:37:47.391028
# Epoch 154:
# 352
# Training loss: 0.4309, Training accuracy: 86.2067 %
# 2019-10-01 02:37:57.179029
# Validation...
# Validation loss: 0.6348, Validation accuracy: 79.7200 %
# Current learning rate has decayed to 0.000020
# 2019-10-01 02:38:02.289028
# Epoch 155:
# 352
# Training loss: 0.4377, Training accuracy: 85.9933 %
# 2019-10-01 02:38:12.031030
# Validation...
# Validation loss: 0.6328, Validation accuracy: 79.8400 %
# 2019-10-01 02:38:17.150030
# Epoch 156:
# 352
# Training loss: 0.4333, Training accuracy: 86.1556 %
# 2019-10-01 02:38:26.903029
# Validation...
# Validation loss: 0.6322, Validation accuracy: 79.7000 %
# Current learning rate has decayed to 0.000018
# 2019-10-01 02:38:32.026029
# Epoch 157:
# 352
# Training loss: 0.4277, Training accuracy: 86.4022 %
# 2019-10-01 02:38:41.786029
# Validation...
# Validation loss: 0.6327, Validation accuracy: 79.7200 %
# 2019-10-01 02:38:46.914030
# Epoch 158:
# 352
# Training loss: 0.4309, Training accuracy: 85.9978 %
# 2019-10-01 02:38:56.606030
# Validation...
# Validation loss: 0.6309, Validation accuracy: 79.7600 %
# Current learning rate has decayed to 0.000017
# 2019-10-01 02:39:01.719032
# Epoch 159:
# 352
# Training loss: 0.4367, Training accuracy: 86.1178 %
# 2019-10-01 02:39:11.478031
# Validation...
# Validation loss: 0.6291, Validation accuracy: 79.7000 %
# 2019-10-01 02:39:16.652028
# Epoch 160:
# 352
# Training loss: 0.4334, Training accuracy: 86.1133 %
# 2019-10-01 02:39:26.348029
# Validation...
# Validation loss: 0.6314, Validation accuracy: 79.6200 %
# Current learning rate has decayed to 0.000016
# 2019-10-01 02:39:31.545030
# Epoch 161:
# 352
# Training loss: 0.4304, Training accuracy: 86.1000 %
# 2019-10-01 02:39:41.223029
# Validation...
# Validation loss: 0.6314, Validation accuracy: 79.7200 %
# 2019-10-01 02:39:46.534029
# Epoch 162:
# 352
# Training loss: 0.4272, Training accuracy: 86.1844 %
# 2019-10-01 02:39:56.265030
# Validation...
# Validation loss: 0.6296, Validation accuracy: 79.6600 %
# Current learning rate has decayed to 0.000014
# 2019-10-01 02:40:01.530543
# Epoch 163:
# 352
# Training loss: 0.4276, Training accuracy: 86.3067 %
# 2019-10-01 02:40:11.268542
# Validation...
# Validation loss: 0.6316, Validation accuracy: 79.7600 %
# 2019-10-01 02:40:16.562572
# Epoch 164:
# 352
# Training loss: 0.4222, Training accuracy: 86.4400 %
# 2019-10-01 02:40:26.263572
# Validation...
# Validation loss: 0.6279, Validation accuracy: 79.6200 %
# Current learning rate has decayed to 0.000013
# 2019-10-01 02:40:31.443571
# Epoch 165:
# 352
# Training loss: 0.4337, Training accuracy: 86.2711 %
# 2019-10-01 02:40:41.109572
# Validation...
# Validation loss: 0.6281, Validation accuracy: 79.8400 %
# 2019-10-01 02:40:46.311571
# Epoch 166:
# 352
# Training loss: 0.4245, Training accuracy: 86.3689 %
# 2019-10-01 02:40:56.063572
# Validation...
# Validation loss: 0.6285, Validation accuracy: 79.8600 %
# Current learning rate has decayed to 0.000012
# 2019-10-01 02:41:01.229572
# Epoch 167:
# 352
# Training loss: 0.4302, Training accuracy: 86.1489 %
# 2019-10-01 02:41:10.987084
# Validation...
# Validation loss: 0.6297, Validation accuracy: 79.6400 %
# 2019-10-01 02:41:16.156085
# Epoch 168:
# 352
# Training loss: 0.4342, Training accuracy: 86.1400 %
# 2019-10-01 02:41:25.934086
# Validation...
# Validation loss: 0.6313, Validation accuracy: 79.6000 %
# Current learning rate has decayed to 0.000011
# 2019-10-01 02:41:31.058084
# Epoch 169:
# 352
# Training loss: 0.4275, Training accuracy: 86.2956 %
# 2019-10-01 02:41:40.784084
# Validation...
# Validation loss: 0.6274, Validation accuracy: 79.7600 %
# 2019-10-01 02:41:45.958085
# Epoch 170:
# 352
# Training loss: 0.4332, Training accuracy: 86.1156 %
# 2019-10-01 02:41:55.697085
# Validation...
# Validation loss: 0.6298, Validation accuracy: 79.6600 %
# Current learning rate has decayed to 0.000010
# 2019-10-01 02:42:00.827757
# Epoch 171:
# 352
# Training loss: 0.4318, Training accuracy: 86.0333 %
# 2019-10-01 02:42:10.598758
# Validation...
# Validation loss: 0.6315, Validation accuracy: 79.6800 %
# 2019-10-01 02:42:15.728756
# Epoch 172:
# 352
# Training loss: 0.4359, Training accuracy: 86.2644 %
# 2019-10-01 02:42:25.526756
# Validation...
# Validation loss: 0.6308, Validation accuracy: 79.7800 %
# Current learning rate has decayed to 0.000010
# 2019-10-01 02:42:30.658757
# Epoch 173:
# 352
# Training loss: 0.4298, Training accuracy: 86.2867 %
# 2019-10-01 02:42:40.371756
# Validation...
# Validation loss: 0.6266, Validation accuracy: 79.5200 %
# 2019-10-01 02:42:45.489758
# Epoch 174:
# 352
# Training loss: 0.4237, Training accuracy: 86.4244 %
# 2019-10-01 02:42:55.207756
# Validation...
# Validation loss: 0.6286, Validation accuracy: 79.5000 %
# Current learning rate has decayed to 0.000009
# 2019-10-01 02:43:00.409757
# Epoch 175:
# 352
# Training loss: 0.4256, Training accuracy: 86.3778 %
# 2019-10-01 02:43:10.136758
# Validation...
# Validation loss: 0.6277, Validation accuracy: 79.6600 %
# 2019-10-01 02:43:15.256756
# Epoch 176:
# 352
# Training loss: 0.4312, Training accuracy: 86.2378 %
# 2019-10-01 02:43:24.924757
# Validation...
# Validation loss: 0.6291, Validation accuracy: 79.6600 %
# Current learning rate has decayed to 0.000008
# 2019-10-01 02:43:30.090758
# Epoch 177:
# 352
# Training loss: 0.4221, Training accuracy: 86.5244 %
# 2019-10-01 02:43:39.771757
# Validation...
# Validation loss: 0.6279, Validation accuracy: 79.7600 %
# 2019-10-01 02:43:44.958756
# Epoch 178:
# 352
# Training loss: 0.4272, Training accuracy: 86.3311 %
# 2019-10-01 02:43:54.696757
# Validation...
# Validation loss: 0.6281, Validation accuracy: 79.8600 %
# Current learning rate has decayed to 0.000008
# 2019-10-01 02:43:59.853757
# Epoch 179:
# 352
# Training loss: 0.4279, Training accuracy: 86.4711 %
# 2019-10-01 02:44:09.630757
# Validation...
# Validation loss: 0.6290, Validation accuracy: 79.7200 %
# 2019-10-01 02:44:14.745758
# Epoch 180:
# 352
# Training loss: 0.4317, Training accuracy: 86.1244 %
# 2019-10-01 02:44:24.572758
# Validation...
# Validation loss: 0.6282, Validation accuracy: 79.5600 %
# Current learning rate has decayed to 0.000007
# 2019-10-01 02:44:29.720756
# Epoch 181:
# 352
# Training loss: 0.4234, Training accuracy: 86.3978 %
# 2019-10-01 02:44:39.517756
# Validation...
# Validation loss: 0.6279, Validation accuracy: 79.6600 %
# 2019-10-01 02:44:44.658757
# Epoch 182:
# 352
# Training loss: 0.4267, Training accuracy: 86.3422 %
# 2019-10-01 02:44:54.424757
# Validation...
# Validation loss: 0.6291, Validation accuracy: 79.4600 %
# Current learning rate has decayed to 0.000006
# 2019-10-01 02:44:59.517756
# Epoch 183:
# 352
# Training loss: 0.4233, Training accuracy: 86.4133 %
# 2019-10-01 02:45:09.267758
# Validation...
# Validation loss: 0.6293, Validation accuracy: 79.5000 %
# 2019-10-01 02:45:14.377757
# Epoch 184:
# 352
# Training loss: 0.4275, Training accuracy: 86.4067 %
# 2019-10-01 02:45:24.238757
# Validation...
# Validation loss: 0.6295, Validation accuracy: 79.5200 %
# Current learning rate has decayed to 0.000006
# 2019-10-01 02:45:29.357345
# Epoch 185:
# 352
# Training loss: 0.4189, Training accuracy: 86.6333 %
# 2019-10-01 02:45:39.065857
# Validation...
# Validation loss: 0.6302, Validation accuracy: 79.8400 %
# 2019-10-01 02:45:44.189857
# Epoch 186:
# 352
# Training loss: 0.4319, Training accuracy: 86.1156 %
# 2019-10-01 02:45:53.879857
# Validation...
# Validation loss: 0.6298, Validation accuracy: 79.5800 %
# Current learning rate has decayed to 0.000005
# 2019-10-01 02:45:58.989857
# Epoch 187:
# 352
# Training loss: 0.4289, Training accuracy: 86.4378 %
# 2019-10-01 02:46:08.716856
# Validation...
# Validation loss: 0.6284, Validation accuracy: 79.6600 %
# 2019-10-01 02:46:13.832858
# Epoch 188:
# 352
# Training loss: 0.4261, Training accuracy: 86.4000 %
# 2019-10-01 02:46:23.571859
# Validation...
# Validation loss: 0.6288, Validation accuracy: 79.8800 %
# Current learning rate has decayed to 0.000005
# 2019-10-01 02:46:28.732857
# Epoch 189:
# 352
# Training loss: 0.4263, Training accuracy: 86.3844 %
# 2019-10-01 02:46:38.444856
# Validation...
# Validation loss: 0.6275, Validation accuracy: 79.7200 %
# 2019-10-01 02:46:43.650857
# Epoch 190:
# 352
# Training loss: 0.4245, Training accuracy: 86.5267 %
# 2019-10-01 02:46:53.338856
# Validation...
# Validation loss: 0.6283, Validation accuracy: 79.8600 %
# Current learning rate has decayed to 0.000005
# 2019-10-01 02:46:58.574857
# Epoch 191:
# 352
# Training loss: 0.4180, Training accuracy: 86.6444 %
# 2019-10-01 02:47:08.250857
# Validation...
# Validation loss: 0.6301, Validation accuracy: 79.6800 %
# 2019-10-01 02:47:13.508857
# Epoch 192:
# 352
# Training loss: 0.4188, Training accuracy: 86.6022 %
# 2019-10-01 02:47:23.223856
# Validation...
# Validation loss: 0.6283, Validation accuracy: 79.8000 %
# Current learning rate has decayed to 0.000004
# 2019-10-01 02:47:28.518857
# Epoch 193:
# 352
# Training loss: 0.4268, Training accuracy: 86.4244 %
# 2019-10-01 02:47:38.230857
# Validation...
# Validation loss: 0.6280, Validation accuracy: 79.6600 %
# 2019-10-01 02:47:43.394856
# Epoch 194:
# 352
# Training loss: 0.4324, Training accuracy: 86.3311 %
# 2019-10-01 02:47:53.092856
# Validation...
# Validation loss: 0.6287, Validation accuracy: 79.6200 %
# Current learning rate has decayed to 0.000004
# 2019-10-01 02:47:58.241857
# Epoch 195:
# 352
# Training loss: 0.4282, Training accuracy: 86.3489 %
# 2019-10-01 02:48:08.058858
# Validation...
# Validation loss: 0.6283, Validation accuracy: 79.8200 %
# 2019-10-01 02:48:13.212857
# Epoch 196:
# 352
# Training loss: 0.4295, Training accuracy: 86.1911 %
# 2019-10-01 02:48:23.041857
# Validation...
# Validation loss: 0.6304, Validation accuracy: 79.6800 %
# Current learning rate has decayed to 0.000004
# 2019-10-01 02:48:28.189857
# Epoch 197:
# 352
# Training loss: 0.4205, Training accuracy: 86.4667 %
# 2019-10-01 02:48:37.917858
# Validation...
# Validation loss: 0.6302, Validation accuracy: 79.9200 %
# 2019-10-01 02:48:43.063857
# Epoch 198:
# 352
# Training loss: 0.4206, Training accuracy: 86.6756 %
# 2019-10-01 02:48:52.911857
# Validation...
# Validation loss: 0.6298, Validation accuracy: 79.5600 %
# Current learning rate has decayed to 0.000003
# 2019-10-01 02:48:58.058858
# Epoch 199:
# 352
# Training loss: 0.4223, Training accuracy: 86.4311 %
# 2019-10-01 02:49:07.820856
# Validation...
# Validation loss: 0.6290, Validation accuracy: 79.6800 %
# Optimization finished.
